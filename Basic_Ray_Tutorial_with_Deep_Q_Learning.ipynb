# %% [markdown]
# ### Basic Ray Tutorial and Deep Q Learning

# %% [markdown]
# In the first part of the tutorial we showcase what ray can do to speed up code and functions.  We will show how a simple decorator function enables a standard written python function to be run in a parallelized manner and distributed across nodes.
#
# The second part of this tutorial focuses on the cart-pole problem. A cart has a pole fixed with a movable lever in the middle of the cart. The cart slides along a frictionless surface. The goal is to keep the pole upright at all times. The test is how far back and forth the cart can move in order to prevent the pole from falling. The tutorial has been modified heavily so that it (i) runs in a jupyter notebook, (ii) demonstrates full capabilities of ray, and ray tune and (iii) breaks down the components of a RL project along with enhanced explainations of the code. We may modify this tutorial further to solve a different problem.
#
# In the third part of the tutorial, we demonstrate how to create a custom reinforcement learning environment with the problem space of a robot walking down a corridor.
#
# #### References:
#
# Barto, A. G., Sutton, R. S. and Anderson, C. (1983), ‘Neuron-like adaptive elements that can solve difficult learning control problems’, IEEE Transactions on Systems, 5, Man, and Cybernetics 13, 834–846
#
# Tune: A Research Platform for Distributed Model Selection and Training, Liaw, Richard and Liang, Eric and Nishihara, Robert and Moritz, Philipp and Gonzalez, Joseph E and Stoica, Ion, arXiv preprint arXiv:1807.05118}, 2018
#
# Ray RLLib Documentation: [Ray RLLib Documentation](https://docs.ray.io/en/latest/rllib-training.html#getting-started)
#
# Ray Tune Documentation: [Ray Tune Documentation](https://docs.ray.io/en/latest/tune/index.html)
#
# Mastering Reinforcement Learning with Python, Enes Bilgin, Packt Publishing, 2020 [Buy MRL with Python](https://www.amazon.com/Mastering-Reinforcement-Learning-Python-next-generation/dp/1838644148/?tag=meastus-200)
#
# Example of Calculating Pi using Ray [How to scale Python multiprocessing to a cluster with one line of code by Evan Oaks](https://medium.com/distributed-computing-with-ray/how-to-scale-python-multiprocessing-to-a-cluster-with-one-line-of-code-d19f242f60ff)

# %% [markdown]
# #### Checking Ray Version, Instantiating Ray Instances and Looking at Node Parameters
#
# Its typically helpful to check the parameters for nodes to ensure that they are in good shape.  One can also navigate to the tab which says 'Ray Web UI) to look through the node pool and ray actors as well as memory.  These are advanced topics and are meant for trouble-shooting only.
#
#
# In this notebook we'll start with showing you how easy it is to use Ray to convert regular functions into ones that are parallelized and distributed across nodes.  Before we do anything though, let's check our version of Ray.

# %%
! ray --version
# Out:
# ray, version 1.9.0

# %%
import ray
import os

if ray.is_initialized() == False:
   service_host = os.environ["RAY_HEAD_SERVICE_HOST"]
   service_port = os.environ["RAY_HEAD_SERVICE_PORT"]
   #_temp_dir='/domino/datasets/local/{}/'.format(os.environ['DOMINO_PROJECT_NAME']) #set to a dataset
   ray.util.connect(f"{service_host}:{service_port}")

# %% [markdown]
# Now let's check the health of the nodes, look at their CPU and GPU per node.  Here you can see each node, including the head node have seven GPUs (this may differ in your example depending on your environment).  It's a good idea to check this and plan for memory usuage with Ray.  If there isn't enough memory overhead for the code as written, a data channel error will shutdown.  There are advanced techniques to prevent this.  This happens regardless of the verison of Ray used, so make sure to check each time.

# %%
ray.nodes()
# Out:
# [{'NodeID': '1fdc47da06fd5fd9ebb7a0d6e25ffef999766db14e84093c6e7da1da',
#   'Alive': True,
#   'NodeManagerAddress': '10.0.45.20',
#   'NodeManagerHostname': 'ray-61ddddeb0bbd833830273b3e-ray-worker-2',
#   'NodeManagerPort': 2385,
#   'ObjectManagerPort': 2384,
#   'ObjectStoreSocketName': '/tmp/ray/session_2022-01-11_19-53-18_620358_1/sockets/plasma_store',
#   'RayletSocketName': '/tmp/ray/session_2022-01-11_19-53-18_620358_1/sockets/raylet',
#   'MetricsExportPort': 58583,
#   'alive': True,
#   'Resources': {'object_store_memory': 8677033574.0,
#    'CPU': 6.0,
#    'memory': 20246411674.0,
#    'node:10.0.45.20': 1.0}},
#  {'NodeID': '28a11237f6f4dfa5845ea45db75eccf3ffb19be11e97e3b9498ab7bc',
#   'Alive': True,
#   'NodeManagerAddress': '10.0.42.199',
#   'NodeManagerHostname': 'ray-61ddddeb0bbd833830273b3e-ray-worker-1',
#   'NodeManagerPort': 2385,
#   'ObjectManagerPort': 2384,
#   'ObjectStoreSocketName': '/tmp/ray/session_2022-01-11_19-53-18_620358_1/sockets/plasma_store',
#   'RayletSocketName': '/tmp/ray/session_2022-01-11_19-53-18_620358_1/sockets/raylet',
#   'MetricsExportPort': 62305,
#   'alive': True,
#   'Resources': {'node:10.0.42.199': 1.0,
#    'CPU': 6.0,
#    'object_store_memory': 8676968448.0,
#    'memory': 20246259712.0}},
#  {'NodeID': '4cf45ef28d4fbd90497188b5678376bb955facc3b04352d5c2dc3ce9',
#   'Alive': True,
#   'NodeManagerAddress': '10.0.35.140',
#   'NodeManagerHostname': 'ray-61ddddeb0bbd833830273b3e-ray-worker-3',
#   'NodeManagerPort': 2385,
#   'ObjectManagerPort': 2384,
#   'ObjectStoreSocketName': '/tmp/ray/session_2022-01-11_19-53-18_620358_1/sockets/plasma_store',
#   'RayletSocketName': '/tmp/ray/session_2022-01-11_19-53-18_620358_1/sockets/raylet',
#   'MetricsExportPort': 57238,
#   'alive': True,
#   'Resources': {'memory': 20250434356.0,
#    'CPU': 6.0,
#    'object_store_memory': 8678757580.0,
#    'node:10.0.35.140': 1.0}},
#  {'NodeID': '11300b795f64464e683105fa3600e8163cc953e3c9d81083dab9bc15',
#   'Alive': True,
#   'NodeManagerAddress': '10.0.57.104',
#   'NodeManagerHostname': 'ray-61ddddeb0bbd833830273b3e-ray-head-0',
#   'NodeManagerPort': 2385,
#   'ObjectManagerPort': 2384,
#   'ObjectStoreSocketName': '/tmp/ray/session_2022-01-11_19-53-18_620358_1/sockets/plasma_store',
#   'RayletSocketName': '/tmp/ray/session_2022-01-11_19-53-18_620358_1/sockets/raylet',
#   'MetricsExportPort': 53992,
#   'alive': True,
#   'Resources': {'CPU': 6.0,
#    'memory': 17357539739.0,
#    'node:10.0.57.104': 1.0,
#    'object_store_memory': 8678769868.0}},
#  {'NodeID': '34353fc15202ff4fab92b09b69db2932157e84a77ac4a183011d5f64',
#   'Alive': True,
#   'NodeManagerAddress': '10.0.60.133',
#   'NodeManagerHostname': 'ray-61ddddeb0bbd833830273b3e-ray-worker-0',
#   'NodeManagerPort': 2385,
#   'ObjectManagerPort': 2384,
#   'ObjectStoreSocketName': '/tmp/ray/session_2022-01-11_19-53-18_620358_1/sockets/plasma_store',
#   'RayletSocketName': '/tmp/ray/session_2022-01-11_19-53-18_620358_1/sockets/raylet',
#   'MetricsExportPort': 58264,
#   'alive': True,
#   'Resources': {'object_store_memory': 8678784614.0,
#    'node:10.0.60.133': 1.0,
#    'CPU': 6.0,
#    'memory': 20250497434.0}}]

# %% [markdown]
# ### What is Ray and what can it do?

# %% [markdown]
# Ray is a flexible distributed computing system available on Domino product on demand.  With Ray one can run code both in parallel or in distributed mode.  Parallel mode refers to running a function on several threads simultaneously in parallel.  This method can also be accomplished on multiple nodes at once (distributed computing).  One will notice that the wall clock time (which we compute below) differs from the compute time.  With multiple nodes or threading (running in a distributed fashion), the compute time is split among nodes.  Thus when we provide a 10 second 'sleep' we can see that the 10 seconds is distributed and so the wall clock time (the time we actually experience) is shorter than compute time.  This is part of the magic of parallel and distributed computing.  Let's take a closer look below.

# %%
import time
import os
import ray


y = 1
object_ref = y

def add(x, a=1):
    if x == 'add':
        answer = a + 1
    else:
        answer = a
    time.sleep(5)
    print(answer)
    
number_add =add('add')
number_none =add('hello')
        
object_ids = []
st = time.time()
for x in range(2):
    x = x
    y_id = add('add')
    object_ids.append(y_id) # the object ids will print out
    
## getting the results to pass to another function
objects = object_ids
end = time.time()
print("Time taken: ", str(end-st))
# Out:
# 2
# 1
# 2
# 2
# Time taken:  10.009105682373047

# %% [markdown]
# ## Creating remote objects
#
# Put an object in Ray's object store, get it out and run the function
# say want to add 10 million and after every million 5 seconds, total processing would be 50 seconds
#
# Do this in ray, and have 3 ray workers, adding 1 million values each,
# after calculating 1 million each sleeps 5 seconds, then total processing takes less than six seconds
# iterations in learning
# ml is already iterative, running partitions on each worker and at the distributed sequentially now paralellized
# call without ray and then with ray
# small amount of data, run and then kick off with same code but a larger data set, locally and in cloud testuse 10 workers, each sleeps 2 seconds, and see the difference

# %%
import ray
import time

y = 1
object_ref = ray.put(y)

@ray.remote
def add(x, a=1):
    if x == 'add':
        answer = a + 1
    else:
        answer = a
    time.sleep(5)
    print(answer)
    
number_add = ray.get(add.remote('add'))
number_none = ray.get(add.remote('hello'))
        
object_ids = []
st = time.time()
for x in range(2):
    x = x
    y_id = add.remote('add')
    object_ids.append(y_id) # the object ids will print out
    
## getting the results to pass to another function
objects = ray.get(object_ids)
end = time.time()
print(str(end-st))

#notice that the process ids (pid) have the same number (223) except for the head node which has the number 221
# Out:
# (add pid=223) 2
# (add pid=223) 1
# 5.062792062759399

# %% [markdown]
# ### Calculate Pi

# %%
import time

import math
import random
import time

def sample(num_samples):
    num_inside = 0
    for _ in range(num_samples):
        x, y = random.uniform(-1, 1), random.uniform(-1, 1)
        if math.hypot(x, y) <= 1:
            num_inside += 1
    return num_inside

def approximate_pi(num_samples):
    start = time.time()
    num_inside = sample(num_samples)
    
    print("pi ~= {}".format((4*num_inside)/num_samples))

# %%
# %%time

approximate_pi(10**8)
# Out:
# (add pid=223) 2
# (add pid=221) 2
# pi ~= 3.14165348
# CPU times: user 1min 25s, sys: 23.7 ms, total: 1min 25s
# Wall time: 1min 25s

# %%
import math
import random
import time

def sample(num_samples):
    num_inside = 0
    for _ in range(num_samples):
        x, y = random.uniform(-1, 1), random.uniform(-1, 1)
        if math.hypot(x, y) <= 1:
            num_inside += 1
    return num_inside

def approximate_pi_parallel(num_samples):
    from multiprocessing.pool import Pool
    pool = Pool()
    
    start = time.time()
    num_inside = 0
    sample_batch_size = 100000
    for result in pool.map(sample, [sample_batch_size for _ in range(num_samples//sample_batch_size)]):
        num_inside += result
        
    print("pi ~= {}".format((4*num_inside)/num_samples))

# %%
# %%time

approximate_pi_parallel(10**8)
# Out:
# pi ~= 3.14166316
# CPU times: user 175 ms, sys: 44.4 ms, total: 220 ms
# Wall time: 28 s

# %%
import math
import random
import time

def sample(num_samples):
    num_inside = 0
    for _ in range(num_samples):
        x, y = random.uniform(-1, 1), random.uniform(-1, 1)
        if math.hypot(x, y) <= 1:
            num_inside += 1
    return num_inside

def approximate_pi_distributed(num_samples):
    from ray.util.multiprocessing.pool import Pool # NOTE: Only the import statement is changed.
    pool = Pool()
        
    start = time.time()
    num_inside = 0
    sample_batch_size = 100000
    for result in pool.map(sample, [sample_batch_size for _ in range(num_samples//sample_batch_size)]):
        num_inside += result
        
    print("pi ~= {}".format((4*num_inside)/num_samples))

# %%
# %%time

approximate_pi_distributed(10**8)
# Out:
# pi ~= 3.14164072
# CPU times: user 327 ms, sys: 20.5 ms, total: 347 ms
# Wall time: 7.55 s

# %% [markdown]
# Notice in the above examples the compute time differs and the wall clock time for the compute differs. However keep in mind Ray is only using one worker to calculate pi in this simple example becasue we started the cluster with one worker.  If the cluster is started with more workers, it will speed up the calculations every further.

# %% [markdown]
# A few more examples below show how to appropriately use Ray to speed up calculations.

# %%
def return_multiple():
    time.sleep(5)
    return 1, 2, 3

st = time.time()
a, b, c = return_multiple()
end = time.time()
print(a,b,c)
print('The wall-clock time is ', str(end-st))
# Out:
# 1 2 3
# The wall-clock time is  5.00536847114563

# %%
@ray.remote(num_returns=3)
def return_multiple():
    time.sleep(5)
    return 1, 2, 3


st = time.time()
a, b, c = return_multiple.remote()
end = time.time()
print(ray.get(a), ray.get(b), ray.get(c))
print('The wall-clock time is ', str(end-st))
# Out:
# 1 2 3
# The wall-clock time is  0.0034894943237304688

# %%
ray.shutdown()

# %% [markdown]
# ### The Cart Pole Problem
#
# Training with hyperparameter tuning was traditionally very human-time intensive. With the Ray 'tune' tool, hyper-parameter tuning is automated.  Ray is not the only software that can do this neat trick of parallel and distributed compute.  It can be done with any distributed system.  Ray just happens to particularlly excell at deeep learning and reinforcement learning.
#
# RLlib is an open-source library for reinforcement learning that offers both high scalability and a unified API for a variety of applications. RLlib natively supports TensorFlow, TensorFlow Eager, and PyTorch, but most of its internals are framework agnostic. See the docs [here](https://docs.ray.io/en/latest/rllib.html) for more information.

# %% [markdown]
# ### Running the Cart-Pole Problem

# %% [markdown]
# #### Determining the best learning rate using Ray's Tune library
#
# The example below shows how to use Ray's Tune library with the cart-pole problem.  The best learning rate can be determined by the reward amount.  Its a best practise to shutdown and re start your distributed computing system each time.  This allows the workers to clear their memory.  In addition the example below is one where we run the cart-pole problem in a distributed manner.  We'll show a second example where we run the experiment in a parallel manner.  In this distributed example you'll see that it takes less than 20 seconds to run the entire training loop.

# %%
import ray
import os

ray.shutdown()

if ray.is_initialized() == False:
   service_host = os.environ["RAY_HEAD_SERVICE_HOST"]
   service_port = os.environ["RAY_HEAD_SERVICE_PORT"]
   _temp_dir='/domino/datasets/local/{}/'.format(os.environ['DOMINO_PROJECT_NAME']) #set to a dataset
   ray.util.connect(f"{service_host}:{service_port}")

# %%
import ray
from ray import tune
from ray.tune.logger import pretty_print


analysis = tune.run(
    "DQN",
    stop={"episode_reward_mean": 1},
    config={
        "env": "CartPole-v0",
        "num_gpus": 0,
        "num_workers": 1,
        "lr": tune.grid_search([0.01, 0.001, 0.0001]),
    },
)

#print("Best configuration: ", analysis.best_config)
ray.shutdown()
# Out:
# (run pid=749) == Status ==
# (run pid=749) Current time: 2022-01-11 19:57:58 (running for 00:00:03.24)
# (run pid=749) Memory usage on this node: 3.7/31.4 GiB
# (run pid=749) Using FIFO scheduling algorithm.
# (run pid=749) Resources requested: 0/30 CPUs, 0/0 GPUs, 0.0/91.6 GiB heap, 0.0/40.41 GiB objects
# (run pid=749) Result logdir: /home/ubuntu/ray_results/DQN
# (run pid=749) Number of trials: 3/3 (3 PENDING)
# (run pid=749) +-----------------------------+----------+-------+--------+
# (run pid=749) | Trial name                  | status   | loc   |     lr |
# (run pid=749) |-----------------------------+----------+-------+--------|
# (run pid=749) | DQN_CartPole-v0_c4071_00000 | PENDING  |       | 0.01   |
# (run pid=749) | DQN_CartPole-v0_c4071_00001 | PENDING  |       | 0.001  |
# (run pid=749) | DQN_CartPole-v0_c4071_00002 | PENDING  |       | 0.0001 |
# (run pid=749) +-----------------------------+----------+-------+--------+
# (run pid=749)
# (run pid=749)
# (DQN pid=240, ip=10.0.35.140) 2022-01-11 19:58:03,356	INFO trainer.py:722 -- Your framework setting is 'tf', meaning you are using static-graph mode. Set framework='tf2' to enable eager execution with tf2.x. You may also want to then set `eager_tracing=True` in order to reach similar execution speed as with static-graph mode.
# (DQN pid=240, ip=10.0.35.140) 2022-01-11 19:58:03,356	INFO dqn.py:141 -- In multi-agent mode, policies will be optimized sequentially by the multi-GPU optimizer. Consider setting simple_optimizer=True if this doesn't work for you.
# (DQN pid=240, ip=10.0.35.140) 2022-01-11 19:58:03,356	INFO trainer.py:743 -- Current log_level is WARN. For more information, set 'log_level': 'INFO' / 'DEBUG' or use the -v and -vv flags.
# (DQN pid=240, ip=10.0.45.20) 2022-01-11 19:58:03,367	INFO trainer.py:722 -- Your framework setting is 'tf', meaning you are using static-graph mode. Set framework='tf2' to enable eager execution with tf2.x. You may also want to then set `eager_tracing=True` in order to reach similar execution speed as with static-graph mode.
# (DQN pid=240, ip=10.0.45.20) 2022-01-11 19:58:03,367	INFO dqn.py:141 -- In multi-agent mode, policies will be optimized sequentially by the multi-GPU optimizer. Consider setting simple_optimizer=True if this doesn't work for you.
# (DQN pid=240, ip=10.0.45.20) 2022-01-11 19:58:03,367	INFO trainer.py:743 -- Current log_level is WARN. For more information, set 'log_level': 'INFO' / 'DEBUG' or use the -v and -vv flags.
# (DQN pid=240, ip=10.0.42.199) 2022-01-11 19:58:03,379	INFO trainer.py:722 -- Your framework setting is 'tf', meaning you are using static-graph mode. Set framework='tf2' to enable eager execution with tf2.x. You may also want to then set `eager_tracing=True` in order to reach similar execution speed as with static-graph mode.
# (DQN pid=240, ip=10.0.42.199) 2022-01-11 19:58:03,380	INFO dqn.py:141 -- In multi-agent mode, policies will be optimized sequentially by the multi-GPU optimizer. Consider setting simple_optimizer=True if this doesn't work for you.
# (DQN pid=240, ip=10.0.42.199) 2022-01-11 19:58:03,380	INFO trainer.py:743 -- Current log_level is WARN. For more information, set 'log_level': 'INFO' / 'DEBUG' or use the -v and -vv flags.
# (RolloutWorker pid=239, ip=10.0.35.140) 2022-01-11 19:58:07,192	WARNING deprecation.py:45 -- DeprecationWarning: `SampleBatch['is_training']` has been deprecated. Use `SampleBatch.is_training` instead. This will raise an error in the future!
# (RolloutWorker pid=239, ip=10.0.42.199) 2022-01-11 19:58:07,283	WARNING deprecation.py:45 -- DeprecationWarning: `SampleBatch['is_training']` has been deprecated. Use `SampleBatch.is_training` instead. This will raise an error in the future!
# (RolloutWorker pid=239, ip=10.0.45.20) 2022-01-11 19:58:07,286	WARNING deprecation.py:45 -- DeprecationWarning: `SampleBatch['is_training']` has been deprecated. Use `SampleBatch.is_training` instead. This will raise an error in the future!
# (DQN pid=240, ip=10.0.35.140) 2022-01-11 19:58:08,908	WARNING deprecation.py:45 -- DeprecationWarning: `SampleBatch['is_training']` has been deprecated. Use `SampleBatch.is_training` instead. This will raise an error in the future!
# (DQN pid=240, ip=10.0.42.199) 2022-01-11 19:58:08,971	WARNING deprecation.py:45 -- DeprecationWarning: `SampleBatch['is_training']` has been deprecated. Use `SampleBatch.is_training` instead. This will raise an error in the future!
# (DQN pid=240, ip=10.0.45.20) 2022-01-11 19:58:08,997	WARNING deprecation.py:45 -- DeprecationWarning: `SampleBatch['is_training']` has been deprecated. Use `SampleBatch.is_training` instead. This will raise an error in the future!
# (run pid=749) == Status ==
# (run pid=749) Current time: 2022-01-11 19:58:10 (running for 00:00:14.82)
# (run pid=749) Memory usage on this node: 3.7/31.4 GiB
# (run pid=749) Using FIFO scheduling algorithm.
# (run pid=749) Resources requested: 6.0/30 CPUs, 0/0 GPUs, 0.0/91.6 GiB heap, 0.0/40.41 GiB objects
# (run pid=749) Result logdir: /home/ubuntu/ray_results/DQN
# (run pid=749) Number of trials: 3/3 (3 RUNNING)
# (run pid=749) +-----------------------------+----------+-----------------+--------+
# (run pid=749) | Trial name                  | status   | loc             |     lr |
# (run pid=749) |-----------------------------+----------+-----------------+--------|
# (run pid=749) | DQN_CartPole-v0_c4071_00000 | RUNNING  | 10.0.35.140:240 | 0.01   |
# (run pid=749) | DQN_CartPole-v0_c4071_00001 | RUNNING  | 10.0.45.20:240  | 0.001  |
# (run pid=749) | DQN_CartPole-v0_c4071_00002 | RUNNING  | 10.0.42.199:240 | 0.0001 |
# (run pid=749) +-----------------------------+----------+-----------------+--------+
# (run pid=749)
# (run pid=749)
# (run pid=749) == Status ==
# (run pid=749) Current time: 2022-01-11 19:58:11 (running for 00:00:15.83)
# (run pid=749) Memory usage on this node: 3.7/31.4 GiB
# (run pid=749) Using FIFO scheduling algorithm.
# (run pid=749) Resources requested: 6.0/30 CPUs, 0/0 GPUs, 0.0/91.6 GiB heap, 0.0/40.41 GiB objects
# (run pid=749) Result logdir: /home/ubuntu/ray_results/DQN
# (run pid=749) Number of trials: 3/3 (3 RUNNING)
# (run pid=749) +-----------------------------+----------+-----------------+--------+
# (run pid=749) | Trial name                  | status   | loc             |     lr |
# (run pid=749) |-----------------------------+----------+-----------------+--------|
# (run pid=749) | DQN_CartPole-v0_c4071_00000 | RUNNING  | 10.0.35.140:240 | 0.01   |
# (run pid=749) | DQN_CartPole-v0_c4071_00001 | RUNNING  | 10.0.45.20:240  | 0.001  |
# (run pid=749) | DQN_CartPole-v0_c4071_00002 | RUNNING  | 10.0.42.199:240 | 0.0001 |
# (run pid=749) +-----------------------------+----------+-----------------+--------+
# (run pid=749)
# (run pid=749)
# (run pid=749) Result for DQN_CartPole-v0_c4071_00000:
# (run pid=749)   agent_timesteps_total: 1000
# (run pid=749)   custom_metrics: {}
# (run pid=749)   date: 2022-01-11_19-58-12
# (run pid=749)   done: true
# (run pid=749)   episode_len_mean: 20.645833333333332
# (run pid=749)   episode_media: {}
# (run pid=749)   episode_reward_max: 56.0
# (run pid=749)   episode_reward_mean: 20.645833333333332
# (run pid=749)   episode_reward_min: 10.0
# (run pid=749)   episodes_this_iter: 48
# (run pid=749)   episodes_total: 48
# (run pid=749)   experiment_id: f7857542abc540cf94537eb897f24cd7
# (run pid=749)   hostname: ray-61ddddeb0bbd833830273b3e-ray-worker-3
# (run pid=749)   info:
# (run pid=749)     last_target_update_ts: 1000
# (run pid=749)     learner:
# (run pid=749)       default_policy:
# (run pid=749)         custom_metrics: {}
# (run pid=749)         learner_stats:
# (run pid=749)           cur_lr: 0.009999999776482582
# (run pid=749)           max_q: 0.42983779311180115
# (run pid=749)           mean_q: -0.10521098226308823
# (run pid=749)           mean_td_error: -1.066210389137268
# (run pid=749)           min_q: -0.6506630182266235
# (run pid=749)           model: {}
# (run pid=749)         td_error:
# (run pid=749)         - -0.8687195777893066
# (run pid=749)         - -0.7844275832176208
# (run pid=749)         - -1.040654182434082
# (run pid=749)         - -1.320429801940918
# (run pid=749)         - -1.2324260473251343
# (run pid=749)         - -1.7653225660324097
# (run pid=749)         - -2.0134963989257812
# (run pid=749)         - -1.4799745082855225
# (run pid=749)         - -0.9577421545982361
# (run pid=749)         - 0.07112887501716614
# (run pid=749)         - -1.4202423095703125
# (run pid=749)         - -1.2352392673492432
# (run pid=749)         - -1.2030775547027588
# (run pid=749)         - -1.189927339553833
# (run pid=749)         - -1.2472221851348877
# (run pid=749)         - -1.34579336643219
# (run pid=749)         - -0.41197821497917175
# (run pid=749)         - -2.115389823913574
# (run pid=749)         - -0.8041847348213196
# (run pid=749)         - -1.2283079624176025
# (run pid=749)         - -0.8144006133079529
# (run pid=749)         - -1.1870205402374268
# (run pid=749)         - -0.7844275832176208
# (run pid=749)         - -0.9781147241592407
# (run pid=749)         - -1.173639178276062
# (run pid=749)         - -0.9804778099060059
# (run pid=749)         - -0.881999135017395
# (run pid=749)         - -0.12741008400917053
# (run pid=749)         - -0.15854111313819885
# (run pid=749)         - -0.6933692693710327
# (run pid=749)         - -1.3839529752731323
# (run pid=749)         - -1.3619524240493774
# (run pid=749)     num_agent_steps_sampled: 1000
# (run pid=749)     num_agent_steps_trained: 32
# (run pid=749)     num_steps_sampled: 1000
# (run pid=749)     num_steps_trained: 32
# (run pid=749)     num_target_updates: 1
# (run pid=749)   iterations_since_restore: 1
# (run pid=749)   node_ip: 10.0.35.140
# (run pid=749)   num_healthy_workers: 1
# (run pid=749)   off_policy_estimator: {}
# (run pid=749)   perf:
# (run pid=749)     cpu_util_percent: 15.250000000000002
# (run pid=749)     ram_util_percent: 11.4
# (run pid=749)   pid: 240
# (run pid=749)   policy_reward_max: {}
# (run pid=749)   policy_reward_mean: {}
# (run pid=749)   policy_reward_min: {}
# (run pid=749)   sampler_perf:
# (run pid=749)     mean_action_processing_ms: 0.07651283309890793
# (run pid=749)     mean_env_render_ms: 0.0
# (run pid=749)     mean_env_wait_ms: 0.07455665748436134
# (run pid=749)     mean_inference_ms: 1.2736337168233378
# (run pid=749)     mean_raw_obs_processing_ms: 0.16759897207284905
# (run pid=749)   time_since_restore: 2.494431734085083
# (run pid=749)   time_this_iter_s: 2.494431734085083
# (run pid=749)   time_total_s: 2.494431734085083
# (run pid=749)   timers:
# (run pid=749)     learn_throughput: 149.207
# (run pid=749)     learn_time_ms: 214.467
# (run pid=749)     load_throughput: 111199.443
# (run pid=749)     load_time_ms: 0.288
# (run pid=749)     update_time_ms: 4.337
# (run pid=749)   timestamp: 1641931092
# (run pid=749)   timesteps_since_restore: 0
# (run pid=749)   timesteps_this_iter: 0
# (run pid=749)   timesteps_total: 1000
# (run pid=749)   training_iteration: 1
# (run pid=749)   trial_id: c4071_00000
# (run pid=749)
# (run pid=749) Result for DQN_CartPole-v0_c4071_00002:
# (run pid=749)   agent_timesteps_total: 1000
# (run pid=749)   custom_metrics: {}
# (run pid=749)   date: 2022-01-11_19-58-12
# (run pid=749)   done: true
# (run pid=749)   episode_len_mean: 23.878048780487806
# (run pid=749)   episode_media: {}
# (run pid=749)   episode_reward_max: 60.0
# (run pid=749)   episode_reward_mean: 23.878048780487806
# (run pid=749)   episode_reward_min: 9.0
# (run pid=749)   episodes_this_iter: 41
# (run pid=749)   episodes_total: 41
# (run pid=749)   experiment_id: 51edf3de14e1474e96b864e50bace764
# (run pid=749)   hostname: ray-61ddddeb0bbd833830273b3e-ray-worker-1
# (run pid=749)   info:
# (run pid=749)     last_target_update_ts: 1000
# (run pid=749)     learner:
# (run pid=749)       default_policy:
# (run pid=749)         custom_metrics: {}
# (run pid=749)         learner_stats:
# (run pid=749)           cur_lr: 9.999999747378752e-05
# (run pid=749)           max_q: 0.586143434047699
# (run pid=749)           mean_q: 0.04528075456619263
# (run pid=749)           mean_td_error: -0.8307848572731018
# (run pid=749)           min_q: -0.5925273299217224
# (run pid=749)           model: {}
# (run pid=749)         td_error:
# (run pid=749)         - -0.9725480675697327
# (run pid=749)         - -1.5328962802886963
# (run pid=749)         - -1.0383223295211792
# (run pid=749)         - -0.9971612691879272
# (run pid=749)         - -0.7809628844261169
# (run pid=749)         - -1.3151063919067383
# (run pid=749)         - -0.6729428172111511
# (run pid=749)         - -0.4083364009857178
# (run pid=749)         - -0.5069684386253357
# (run pid=749)         - -0.9565554857254028
# (run pid=749)         - -0.7577305436134338
# (run pid=749)         - -0.8989891409873962
# (run pid=749)         - -0.9866034388542175
# (run pid=749)         - -0.587016761302948
# (run pid=749)         - -0.17906159162521362
# (run pid=749)         - -1.1975454092025757
# (run pid=749)         - -0.5490651726722717
# (run pid=749)         - -0.9444308280944824
# (run pid=749)         - -0.6486871242523193
# (run pid=749)         - -1.407082438468933
# (run pid=749)         - -0.2912624180316925
# (run pid=749)         - -0.8748781085014343
# (run pid=749)         - -1.012830376625061
# (run pid=749)         - -0.8499972820281982
# (run pid=749)         - 0.1674979329109192
# (run pid=749)         - -0.4629307687282562
# (run pid=749)         - -0.6326797008514404
# (run pid=749)         - -0.8989891409873962
# (run pid=749)         - -1.2937794923782349
# (run pid=749)         - -0.3966834545135498
# (run pid=749)         - -1.010892391204834
# (run pid=749)         - -1.6896767616271973
# (run pid=749)     num_agent_steps_sampled: 1000
# (run pid=749)     num_agent_steps_trained: 32
# (run pid=749)     num_steps_sampled: 1000
# (run pid=749)     num_steps_trained: 32
# (run pid=749)     num_target_updates: 1
# (run pid=749)   iterations_since_restore: 1
# (run pid=749)   node_ip: 10.0.42.199
# (run pid=749)   num_healthy_workers: 1
# (run pid=749)   off_policy_estimator: {}
# (run pid=749)   perf:
# (run pid=749)     cpu_util_percent: 14.85
# (run pid=749)     ram_util_percent: 11.4
# (run pid=749)   pid: 240
# (run pid=749)   policy_reward_max: {}
# (run pid=749)   policy_reward_mean: {}
# (run pid=749)   policy_reward_min: {}
# (run pid=749)   sampler_perf:
# (run pid=749)     mean_action_processing_ms: 0.07846305420348693
# (run pid=749)     mean_env_render_ms: 0.0
# (run pid=749)     mean_env_wait_ms: 0.07775637296053556
# (run pid=749)     mean_inference_ms: 1.2937923530479531
# (run pid=749)     mean_raw_obs_processing_ms: 0.1681903740028282
# (run pid=749)   time_since_restore: 2.5267319679260254
# (run pid=749)   time_this_iter_s: 2.5267319679260254
# (run pid=749)   time_total_s: 2.5267319679260254
# (run pid=749)   timers:
# (run pid=749)     learn_throughput: 146.07
# (run pid=749)     learn_time_ms: 219.074
# (run pid=749)     load_throughput: 110104.781
# (run pid=749)     load_time_ms: 0.291
# (run pid=749)     update_time_ms: 4.351
# (run pid=749)   timestamp: 1641931092
# (run pid=749)   timesteps_since_restore: 0
# (run pid=749)   timesteps_this_iter: 0
# (run pid=749)   timesteps_total: 1000
# (run pid=749)   training_iteration: 1
# (run pid=749)   trial_id: c4071_00002
# (run pid=749)
# (run pid=749) Result for DQN_CartPole-v0_c4071_00001:
# (run pid=749)   agent_timesteps_total: 1000
# (run pid=749)   custom_metrics: {}
# (run pid=749)   date: 2022-01-11_19-58-12
# (run pid=749)   done: true
# (run pid=749)   episode_len_mean: 23.69047619047619
# (run pid=749)   episode_media: {}
# (run pid=749)   episode_reward_max: 67.0
# (run pid=749)   episode_reward_mean: 23.69047619047619
# (run pid=749)   episode_reward_min: 8.0
# (run pid=749)   episodes_this_iter: 42
# (run pid=749)   episodes_total: 42
# (run pid=749)   experiment_id: bb9193602dd0453fac025b8e4bcf5de6
# (run pid=749)   hostname: ray-61ddddeb0bbd833830273b3e-ray-worker-2
# (run pid=749)   info:
# (run pid=749)     last_target_update_ts: 1000
# (run pid=749)     learner:
# (run pid=749)       default_policy:
# (run pid=749)         custom_metrics: {}
# (run pid=749)         learner_stats:
# (run pid=749)           cur_lr: 0.0010000000474974513
# (run pid=749)           max_q: 1.0182312726974487
# (run pid=749)           mean_q: 0.1668786108493805
# (run pid=749)           mean_td_error: -0.4615628123283386
# (run pid=749)           min_q: -0.447528213262558
# (run pid=749)           model: {}
# (run pid=749)         td_error:
# (run pid=749)         - 0.1360006332397461
# (run pid=749)         - -0.7655899524688721
# (run pid=749)         - -0.8096704483032227
# (run pid=749)         - 0.02659916877746582
# (run pid=749)         - -0.4849441945552826
# (run pid=749)         - 0.01823127269744873
# (run pid=749)         - -0.607723593711853
# (run pid=749)         - -0.3809570074081421
# (run pid=749)         - -0.7599583864212036
# (run pid=749)         - -0.3957235813140869
# (run pid=749)         - -0.6847288608551025
# (run pid=749)         - 0.31447017192840576
# (run pid=749)         - 0.2585628628730774
# (run pid=749)         - -0.7480981945991516
# (run pid=749)         - -0.600443422794342
# (run pid=749)         - -0.2846564054489136
# (run pid=749)         - -0.519711971282959
# (run pid=749)         - -0.7853343486785889
# (run pid=749)         - -0.7503695487976074
# (run pid=749)         - -0.8608301281929016
# (run pid=749)         - -0.7415059208869934
# (run pid=749)         - -0.8890601992607117
# (run pid=749)         - -0.61260986328125
# (run pid=749)         - -0.5753602981567383
# (run pid=749)         - -0.8638242483139038
# (run pid=749)         - -0.826174259185791
# (run pid=749)         - -0.12586739659309387
# (run pid=749)         - 0.2815729081630707
# (run pid=749)         - -0.871785044670105
# (run pid=749)         - -0.4713624119758606
# (run pid=749)         - 0.47851306200027466
# (run pid=749)         - -0.8676707744598389
# (run pid=749)     num_agent_steps_sampled: 1000
# (run pid=749)     num_agent_steps_trained: 32
# (run pid=749)     num_steps_sampled: 1000
# (run pid=749)     num_steps_trained: 32
# (run pid=749)     num_target_updates: 1
# (run pid=749)   iterations_since_restore: 1
# (run pid=749)   node_ip: 10.0.45.20
# (run pid=749)   num_healthy_workers: 1
# (run pid=749)   off_policy_estimator: {}
# (run pid=749)   perf:
# (run pid=749)     cpu_util_percent: 15.725000000000001
# (run pid=749)     ram_util_percent: 11.55
# (run pid=749)   pid: 240
# (run pid=749)   policy_reward_max: {}
# (run pid=749)   policy_reward_mean: {}
# (run pid=749)   policy_reward_min: {}
# (run pid=749)   sampler_perf:
# (run pid=749)     mean_action_processing_ms: 0.0792664366883117
# (run pid=749)     mean_env_render_ms: 0.0
# (run pid=749)     mean_env_wait_ms: 0.07924666771521936
# (run pid=749)     mean_inference_ms: 1.3214565299964929
# (run pid=749)     mean_raw_obs_processing_ms: 0.17108259858427705
# (run pid=749)   time_since_restore: 2.565775156021118
# (run pid=749)   time_this_iter_s: 2.565775156021118
# (run pid=749)   time_total_s: 2.565775156021118
# (run pid=749)   timers:
# (run pid=749)     learn_throughput: 150.212
# (run pid=749)     learn_time_ms: 213.033
# (run pid=749)     load_throughput: 100087.791
# (run pid=749)     load_time_ms: 0.32
# (run pid=749)     update_time_ms: 4.507
# (run pid=749)   timestamp: 1641931092
# (run pid=749)   timesteps_since_restore: 0
# (run pid=749)   timesteps_this_iter: 0
# (run pid=749)   timesteps_total: 1000
# (run pid=749)   training_iteration: 1
# (run pid=749)   trial_id: c4071_00001
# (run pid=749)
# (run pid=749) == Status ==
# (run pid=749) Current time: 2022-01-11 19:58:12 (running for 00:00:17.46)
# (run pid=749) Memory usage on this node: 3.7/31.4 GiB
# (run pid=749) Using FIFO scheduling algorithm.
# (run pid=749) Resources requested: 0/30 CPUs, 0/0 GPUs, 0.0/91.6 GiB heap, 0.0/40.41 GiB objects
# (run pid=749) Result logdir: /home/ubuntu/ray_results/DQN
# (run pid=749) Number of trials: 3/3 (3 TERMINATED)
# (run pid=749) +-----------------------------+------------+-----------------+--------+--------+------------------+------+----------+----------------------+----------------------+--------------------+
# (run pid=749) | Trial name                  | status     | loc             |     lr |   iter |   total time (s) |   ts |   reward |   episode_reward_max |   episode_reward_min |   episode_len_mean |
# (run pid=749) |-----------------------------+------------+-----------------+--------+--------+------------------+------+----------+----------------------+----------------------+--------------------|
# (run pid=749) | DQN_CartPole-v0_c4071_00000 | TERMINATED | 10.0.35.140:240 | 0.01   |      1 |          2.49443 | 1000 |  20.6458 |                   56 |                   10 |            20.6458 |
# (run pid=749) | DQN_CartPole-v0_c4071_00001 | TERMINATED | 10.0.45.20:240  | 0.001  |      1 |          2.56578 | 1000 |  23.6905 |                   67 |                    8 |            23.6905 |
# (run pid=749) | DQN_CartPole-v0_c4071_00002 | TERMINATED | 10.0.42.199:240 | 0.0001 |      1 |          2.52673 | 1000 |  23.878  |                   60 |                    9 |            23.878  |
# (run pid=749) +-----------------------------+------------+-----------------+--------+--------+------------------+------+----------+----------------------+----------------------+--------------------+
# (run pid=749)
# (run pid=749)
# (run pid=749) 2022-01-11 19:58:12,994	INFO tune.py:626 -- Total run time: 18.32 seconds (17.42 seconds for the tuning loop).

# %% [markdown]
# #### Looping through multiple iterations to find the best policy
#
# In this example we see that a single node can perform the training.  It takes less than a minute to finish the training loop.  After the data is collected from the training iterations (10), we can look at the results to determine the maximum, mean and minimum reward.  We graph that.  For this notebook you can choose which log files you would like to see using the input.  See what your results look like!

# %%
ray.shutdown()
ray.init()
# Out:
# 2022-01-11 19:58:22,956	INFO services.py:1338 -- View the Ray dashboard at http://127.0.0.1:8265
# 2022-01-11 19:58:22,960	WARNING services.py:1816 -- WARNING: The object store is using /tmp instead of /dev/shm because /dev/shm has only 67108864 bytes available. This will harm performance! You may be able to free up space by deleting files in /dev/shm. If you are inside a Docker container, you can increase /dev/shm size by passing '--shm-size=8.77gb' to 'docker run' (or add it to the run_options list in a Ray cluster config). Make sure to set this to more than 30% of available RAM.
# {'node_ip_address': '10.0.47.167',
#  'raylet_ip_address': '10.0.47.167',
#  'redis_address': '10.0.47.167:6379',
#  'object_store_address': '/tmp/ray/session_2022-01-11_19-58-20_349079_632/sockets/plasma_store',
#  'raylet_socket_name': '/tmp/ray/session_2022-01-11_19-58-20_349079_632/sockets/raylet',
#  'webui_url': '127.0.0.1:8265',
#  'session_dir': '/tmp/ray/session_2022-01-11_19-58-20_349079_632',
#  'metrics_export_port': 61240,
#  'node_id': 'a0473c6cd3151a9a5cfc78d9769053cd8c3f06cfd24cfd382f835f6a'}

# %%
import ray
import ray.rllib.agents.dqn as dqn
from ray.tune.logger import pretty_print

config = dqn.DEFAULT_CONFIG.copy()
config["num_gpus"] = 0
config["num_workers"] = 1
trainer = dqn.DQNTrainer(config=config, env="CartPole-v0")

# Can optionally call trainer.restore(path) to load a checkpoint.

for i in range(10):
   # Perform one iteration of training the policy with PPO
   result = trainer.train()
   print(pretty_print(result))

   if i % 100 == 0:
       checkpoint = trainer.save()
       print("checkpoint saved at", checkpoint)
# Out:
# 2022-01-11 19:58:24,915	INFO trainer.py:722 -- Your framework setting is 'tf', meaning you are using static-graph mode. Set framework='tf2' to enable eager execution with tf2.x. You may also want to then set `eager_tracing=True` in order to reach similar execution speed as with static-graph mode.
# 2022-01-11 19:58:24,916	INFO dqn.py:141 -- In multi-agent mode, policies will be optimized sequentially by the multi-GPU optimizer. Consider setting simple_optimizer=True if this doesn't work for you.
# 2022-01-11 19:58:24,917	INFO trainer.py:743 -- Current log_level is WARN. For more information, set 'log_level': 'INFO' / 'DEBUG' or use the -v and -vv flags.
# (RolloutWorker pid=816) 2022-01-11 19:58:29,337	WARNING deprecation.py:45 -- DeprecationWarning: `SampleBatch['is_training']` has been deprecated. Use `SampleBatch.is_training` instead. This will raise an error in the future!
# 2022-01-11 19:58:30,965	WARNING deprecation.py:45 -- DeprecationWarning: `SampleBatch['is_training']` has been deprecated. Use `SampleBatch.is_training` instead. This will raise an error in the future!
# agent_timesteps_total: 1000
# custom_metrics: {}
# date: 2022-01-11_19-58-34
# done: false
# episode_len_mean: 21.88888888888889
# episode_media: {}
# episode_reward_max: 53.0
# episode_reward_mean: 21.88888888888889
# episode_reward_min: 9.0
# episodes_this_iter: 45
# episodes_total: 45
# experiment_id: b244bf13b9b945709ab62fc7ab5c0c02
# hostname: run-61ddddeb0bbd833830273b3e-4dg5f
# info:
#   last_target_update_ts: 1000
#   learner:
#     default_policy:
#       custom_metrics: {}
#       learner_stats:
#         cur_lr: 0.0005000000237487257
#         max_q: 0.9746882915496826
#         mean_q: 0.021092485636472702
#         mean_td_error: -0.6288041472434998
#         min_q: -0.608495831489563
#         model: {}
#       td_error:
#       - -1.0691776275634766
#       - -0.22702759504318237
#       - -0.6174243688583374
#       - -1.0176359415054321
#       - -0.014757335186004639
#       - -1.0878559350967407
#       - -0.17425566911697388
#       - -0.9877854585647583
#       - -0.9409912824630737
#       - -0.8639929890632629
#       - -0.8982413411140442
#       - 0.22982561588287354
#       - -0.6192736029624939
#       - -0.5149320363998413
#       - -0.7402275204658508
#       - -0.9744658470153809
#       - -1.1575816869735718
#       - -0.8670454025268555
#       - -0.7087262272834778
#       - -0.8058916330337524
#       - -0.8547499775886536
#       - 0.09230631589889526
#       - -0.6499912738800049
#       - -0.8188586831092834
#       - -0.03899890184402466
#       - -0.8191032409667969
#       - -0.047020018100738525
#       - -0.17647784948349
#       - -0.6263668537139893
#       - -0.5756984949111938
#       - -0.6499913334846497
#       - -0.8993181586265564
#   num_agent_steps_sampled: 1000
#   num_agent_steps_trained: 32
#   num_steps_sampled: 1000
#   num_steps_trained: 32
#   num_target_updates: 1
# iterations_since_restore: 1
# node_ip: 10.0.47.167
# num_healthy_workers: 1
# off_policy_estimator: {}
# perf:
#   cpu_util_percent: 16.025
#   ram_util_percent: 14.7
# pid: 632
# policy_reward_max: {}
# policy_reward_mean: {}
# policy_reward_min: {}
# sampler_perf:
#   mean_action_processing_ms: 0.07888772985437414
#   mean_env_render_ms: 0.0
#   mean_env_wait_ms: 0.07856428087293565
#   mean_inference_ms: 1.2076517918726781
#   mean_raw_obs_processing_ms: 0.17377403708961936
# time_since_restore: 2.4939827919006348
# time_this_iter_s: 2.4939827919006348
# time_total_s: 2.4939827919006348
# timers:
#   learn_throughput: 150.144
#   learn_time_ms: 213.129
#   load_throughput: 108240.103
#   load_time_ms: 0.296
#   update_time_ms: 6.11
# timestamp: 1641931114
# timesteps_since_restore: 0
# timesteps_this_iter: 0
# timesteps_total: 1000
# training_iteration: 1
# trial_id: default
#
# checkpoint saved at /home/ubuntu/ray_results/DQN_CartPole-v0_2022-01-11_19-58-24rg2tyl6a/checkpoint_000001/checkpoint-1
# agent_timesteps_total: 2000
# custom_metrics: {}
# date: 2022-01-11_19-58-40
# done: false
# episode_len_mean: 20.091836734693878
# episode_media: {}
# episode_reward_max: 53.0
# episode_reward_mean: 20.091836734693878
# episode_reward_min: 9.0
# episodes_this_iter: 53
# episodes_total: 98
# experiment_id: b244bf13b9b945709ab62fc7ab5c0c02
# hostname: run-61ddddeb0bbd833830273b3e-4dg5f
# info:
#   last_target_update_ts: 1504
#   learner:
#     default_policy:
#       custom_metrics: {}
#       learner_stats:
#         cur_lr: 0.0005000000237487257
#         max_q: 3.663027286529541
#         mean_q: 2.5119946002960205
#         mean_td_error: 0.11730653047561646
#         min_q: 1.9546793699264526
#         model: {}
#       td_error:
#       - 0.06405282020568848
#       - 0.07242774963378906
#       - -0.09928369522094727
#       - 0.354320764541626
#       - 0.9546793699264526
#       - -0.0504305362701416
#       - 1.222571849822998
#       - -0.0368809700012207
#       - 0.16969728469848633
#       - -0.10902595520019531
#       - 0.054564714431762695
#       - -0.016575336456298828
#       - 0.028285741806030273
#       - -0.06340789794921875
#       - 0.9911773204803467
#       - 0.03569936752319336
#       - -0.21771812438964844
#       - 0.09718060493469238
#       - -0.07003259658813477
#       - -0.12677836418151855
#       - -0.918391227722168
#       - 1.062638521194458
#       - 0.02371501922607422
#       - 1.0633759498596191
#       - -0.22149395942687988
#       - 0.02574896812438965
#       - 0.23399710655212402
#       - -0.17935562133789062
#       - -1.1488494873046875
#       - 0.2760782241821289
#       - 0.2610023021697998
#       - 0.02081918716430664
#   num_agent_steps_sampled: 2000
#   num_agent_steps_trained: 8032
#   num_steps_sampled: 2000
#   num_steps_trained: 8032
#   num_steps_trained_this_iter: 0
#   num_target_updates: 2
# iterations_since_restore: 2
# node_ip: 10.0.47.167
# num_healthy_workers: 1
# off_policy_estimator: {}
# perf:
#   cpu_util_percent: 22.55
#   ram_util_percent: 14.7625
# pid: 632
# policy_reward_max: {}
# policy_reward_mean: {}
# policy_reward_min: {}
# sampler_perf:
#   mean_action_processing_ms: 0.07841487520657762
#   mean_env_render_ms: 0.0
#   mean_env_wait_ms: 0.07886234080381074
#   mean_inference_ms: 1.1941705180272277
#   mean_raw_obs_processing_ms: 0.1752820732535825
# time_since_restore: 8.278634071350098
# time_this_iter_s: 5.784651279449463
# time_total_s: 8.278634071350098
# timers:
#   learn_throughput: 9042.311
#   learn_time_ms: 3.539
#   load_throughput: 129254.361
#   load_time_ms: 0.248
#   update_time_ms: 2.553
# timestamp: 1641931120
# timesteps_since_restore: 0
# timesteps_this_iter: 0
# timesteps_total: 2000
# training_iteration: 2
# trial_id: default
#
# agent_timesteps_total: 3000
# custom_metrics: {}
# date: 2022-01-11_19-58-46
# done: false
# episode_len_mean: 21.21
# episode_media: {}
# episode_reward_max: 78.0
# episode_reward_mean: 21.21
# episode_reward_min: 9.0
# episodes_this_iter: 40
# episodes_total: 138
# experiment_id: b244bf13b9b945709ab62fc7ab5c0c02
# hostname: run-61ddddeb0bbd833830273b3e-4dg5f
# info:
#   last_target_update_ts: 2512
#   learner:
#     default_policy:
#       custom_metrics: {}
#       learner_stats:
#         cur_lr: 0.0005000000237487257
#         max_q: 5.235931396484375
#         mean_q: 3.8122873306274414
#         mean_td_error: 0.2742937207221985
#         min_q: 1.5334689617156982
#         model: {}
#       td_error:
#       - -0.05341958999633789
#       - -1.2080200910568237
#       - 2.5260353088378906
#       - -0.18850326538085938
#       - -0.01813483238220215
#       - -0.04952239990234375
#       - 0.1750493049621582
#       - 0.7042008638381958
#       - 2.075817108154297
#       - 1.6441864967346191
#       - 0.024903297424316406
#       - 1.9563822746276855
#       - 0.5334689617156982
#       - -0.04748678207397461
#       - -0.10013866424560547
#       - 0.7013908624649048
#       - -0.28694629669189453
#       - -0.08026742935180664
#       - 0.9470844268798828
#       - 0.38890790939331055
#       - -0.12898492813110352
#       - -0.9919095039367676
#       - -0.06015777587890625
#       - -0.2175273895263672
#       - 1.3404922485351562
#       - -0.21155881881713867
#       - 0.08202028274536133
#       - 0.22251558303833008
#       - -0.5901246070861816
#       - -0.19370341300964355
#       - 0.13236284255981445
#       - -0.25101327896118164
#   num_agent_steps_sampled: 3000
#   num_agent_steps_trained: 16032
#   num_steps_sampled: 3000
#   num_steps_trained: 16032
#   num_steps_trained_this_iter: 0
#   num_target_updates: 4
# iterations_since_restore: 3
# node_ip: 10.0.47.167
# num_healthy_workers: 1
# off_policy_estimator: {}
# perf:
#   cpu_util_percent: 23.299999999999997
#   ram_util_percent: 14.8
# pid: 632
# policy_reward_max: {}
# policy_reward_mean: {}
# policy_reward_min: {}
# sampler_perf:
#   mean_action_processing_ms: 0.07796201025642445
#   mean_env_render_ms: 0.0
#   mean_env_wait_ms: 0.07916158223789026
#   mean_inference_ms: 1.1805850612640214
#   mean_raw_obs_processing_ms: 0.17555532530992482
# time_since_restore: 13.965776920318604
# time_this_iter_s: 5.687142848968506
# time_total_s: 13.965776920318604
# timers:
#   learn_throughput: 8430.126
#   learn_time_ms: 3.796
#   load_throughput: 126584.672
#   load_time_ms: 0.253
#   update_time_ms: 2.67
# timestamp: 1641931126
# timesteps_since_restore: 0
# timesteps_this_iter: 0
# timesteps_total: 3000
# training_iteration: 3
# trial_id: default
#
# agent_timesteps_total: 4000
# custom_metrics: {}
# date: 2022-01-11_19-58-51
# done: false
# episode_len_mean: 26.07
# episode_media: {}
# episode_reward_max: 80.0
# episode_reward_mean: 26.07
# episode_reward_min: 9.0
# episodes_this_iter: 26
# episodes_total: 164
# experiment_id: b244bf13b9b945709ab62fc7ab5c0c02
# hostname: run-61ddddeb0bbd833830273b3e-4dg5f
# info:
#   last_target_update_ts: 3520
#   learner:
#     default_policy:
#       custom_metrics: {}
#       learner_stats:
#         cur_lr: 0.0005000000237487257
#         max_q: 7.757924556732178
#         mean_q: 5.897418022155762
#         mean_td_error: -0.10573864728212357
#         min_q: 1.2117247581481934
#         model: {}
#       td_error:
#       - -1.5071988105773926
#       - 0.16314983367919922
#       - 0.2651515007019043
#       - -0.32310914993286133
#       - 0.264406681060791
#       - 0.4106912612915039
#       - 0.23987388610839844
#       - 0.21172475814819336
#       - -0.1673717498779297
#       - 0.17961406707763672
#       - 0.12034845352172852
#       - -1.0412354469299316
#       - -0.08154535293579102
#       - 0.04455375671386719
#       - -0.17339754104614258
#       - 0.05551338195800781
#       - -0.07104825973510742
#       - -1.0612778663635254
#       - -0.46730995178222656
#       - 0.13152647018432617
#       - -0.005871772766113281
#       - 0.2584547996520996
#       - 0.18304157257080078
#       - -1.2158730030059814
#       - 1.5640978813171387
#       - -0.14909887313842773
#       - 0.1357436180114746
#       - -1.3085556030273438
#       - -0.07461881637573242
#       - 0.2446737289428711
#       - 0.0816488265991211
#       - -0.29033899307250977
#   num_agent_steps_sampled: 4000
#   num_agent_steps_trained: 24032
#   num_steps_sampled: 4000
#   num_steps_trained: 24032
#   num_steps_trained_this_iter: 0
#   num_target_updates: 6
# iterations_since_restore: 4
# node_ip: 10.0.47.167
# num_healthy_workers: 1
# off_policy_estimator: {}
# perf:
#   cpu_util_percent: 23.225
#   ram_util_percent: 14.8
# pid: 632
# policy_reward_max: {}
# policy_reward_mean: {}
# policy_reward_min: {}
# sampler_perf:
#   mean_action_processing_ms: 0.07777923389441546
#   mean_env_render_ms: 0.0
#   mean_env_wait_ms: 0.07925286706844333
#   mean_inference_ms: 1.1747317235527168
#   mean_raw_obs_processing_ms: 0.17465418570903413
# time_since_restore: 19.65340757369995
# time_this_iter_s: 5.687630653381348
# time_total_s: 19.65340757369995
# timers:
#   learn_throughput: 8790.268
#   learn_time_ms: 3.64
#   load_throughput: 119114.065
#   load_time_ms: 0.269
#   update_time_ms: 2.651
# timestamp: 1641931131
# timesteps_since_restore: 0
# timesteps_this_iter: 0
# timesteps_total: 4000
# training_iteration: 4
# trial_id: default
# agent_timesteps_total: 5000
# custom_metrics: {}
# date: 2022-01-11_19-58-57
# done: false
# episode_len_mean: 32.67
# episode_media: {}
# episode_reward_max: 137.0
# episode_reward_mean: 32.67
# episode_reward_min: 9.0
# episodes_this_iter: 15
# episodes_total: 179
# experiment_id: b244bf13b9b945709ab62fc7ab5c0c02
# hostname: run-61ddddeb0bbd833830273b3e-4dg5f
# info:
#   last_target_update_ts: 4528
#   learner:
#     default_policy:
#       custom_metrics: {}
#       learner_stats:
#         cur_lr: 0.0005000000237487257
#         max_q: 9.411138534545898
#         mean_q: 7.446834564208984
#         mean_td_error: 0.03650594502687454
#         min_q: 0.6377754807472229
#         model: {}
#       td_error:
#       - -0.010603904724121094
#       - -0.3622245192527771
#       - -1.2302374839782715
#       - 0.054495811462402344
#       - 0.3911733627319336
#       - -0.19349908828735352
#       - 0.1873607635498047
#       - 0.024274826049804688
#       - 1.4294769763946533
#       - 4.790866374969482
#       - 0.02715778350830078
#       - -0.8322386741638184
#       - -0.17174434661865234
#       - -0.47800588607788086
#       - -0.2124471664428711
#       - -0.8016009330749512
#       - -0.03728771209716797
#       - 0.232635498046875
#       - 0.07146358489990234
#       - 0.29572200775146484
#       - -0.005509376525878906
#       - -0.18052387237548828
#       - 0.1694316864013672
#       - 0.04206085205078125
#       - -0.7321500778198242
#       - 0.039908409118652344
#       - -0.14357852935791016
#       - -1.5024051666259766
#       - -0.017892837524414062
#       - 0.06774616241455078
#       - -0.1395120620727539
#       - 0.3958778381347656
#   num_agent_steps_sampled: 5000
#   num_agent_steps_trained: 32032
#   num_steps_sampled: 5000
#   num_steps_trained: 32032
#   num_steps_trained_this_iter: 0
#   num_target_updates: 8
# iterations_since_restore: 5
# node_ip: 10.0.47.167
# num_healthy_workers: 1
# off_policy_estimator: {}
# perf:
#   cpu_util_percent: 22.950000000000003
#   ram_util_percent: 14.8125
# pid: 632
# policy_reward_max: {}
# policy_reward_mean: {}
# policy_reward_min: {}
# sampler_perf:
#   mean_action_processing_ms: 0.07771423957269276
#   mean_env_render_ms: 0.0
#   mean_env_wait_ms: 0.07928602506528602
#   mean_inference_ms: 1.1718271005886896
#   mean_raw_obs_processing_ms: 0.17365403503794924
# time_since_restore: 25.341490983963013
# time_this_iter_s: 5.6880834102630615
# time_total_s: 25.341490983963013
# timers:
#   learn_throughput: 9095.252
#   learn_time_ms: 3.518
#   load_throughput: 124552.457
#   load_time_ms: 0.257
#   update_time_ms: 2.549
# timestamp: 1641931137
# timesteps_since_restore: 0
# timesteps_this_iter: 0
# timesteps_total: 5000
# training_iteration: 5
# trial_id: default
#
# agent_timesteps_total: 6000
# custom_metrics: {}
# date: 2022-01-11_19-59-03
# done: false
# episode_len_mean: 40.82
# episode_media: {}
# episode_reward_max: 150.0
# episode_reward_mean: 40.82
# episode_reward_min: 9.0
# episodes_this_iter: 13
# episodes_total: 192
# experiment_id: b244bf13b9b945709ab62fc7ab5c0c02
# hostname: run-61ddddeb0bbd833830273b3e-4dg5f
# info:
#   last_target_update_ts: 5536
#   learner:
#     default_policy:
#       custom_metrics: {}
#       learner_stats:
#         cur_lr: 0.0005000000237487257
#         max_q: 11.340778350830078
#         mean_q: 9.11974811553955
#         mean_td_error: 0.6075307130813599
#         min_q: 0.3063364624977112
#         model: {}
#       td_error:
#       - -0.052620887756347656
#       - 0.1474447250366211
#       - -0.48354148864746094
#       - -0.4393796920776367
#       - 7.0564165115356445
#       - -0.34932613372802734
#       - -0.6936635375022888
#       - 7.0564165115356445
#       - -0.09675884246826172
#       - 0.3754568099975586
#       - -0.11873340606689453
#       - 0.6680545806884766
#       - 0.03704261779785156
#       - 0.2039012908935547
#       - 0.20334529876708984
#       - 1.8918466567993164
#       - 0.03462409973144531
#       - -0.4355735778808594
#       - 0.17548370361328125
#       - 0.1197195053100586
#       - 3.029191493988037
#       - 0.3816967010498047
#       - -0.0937422513961792
#       - 0.321197509765625
#       - 0.24734783172607422
#       - -0.14447975158691406
#       - -0.13870906829833984
#       - 0.2112560272216797
#       - -0.16086196899414062
#       - 0.3205547332763672
#       - 0.10709953308105469
#       - 0.06027793884277344
#   num_agent_steps_sampled: 6000
#   num_agent_steps_trained: 40032
#   num_steps_sampled: 6000
#   num_steps_trained: 40032
#   num_steps_trained_this_iter: 0
#   num_target_updates: 10
# iterations_since_restore: 6
# node_ip: 10.0.47.167
# num_healthy_workers: 1
# off_policy_estimator: {}
# perf:
#   cpu_util_percent: 23.0875
#   ram_util_percent: 14.8875
# pid: 632
# policy_reward_max: {}
# policy_reward_mean: {}
# policy_reward_min: {}
# sampler_perf:
#   mean_action_processing_ms: 0.07767685839576302
#   mean_env_render_ms: 0.0
#   mean_env_wait_ms: 0.07934568798819024
#   mean_inference_ms: 1.169395908205255
#   mean_raw_obs_processing_ms: 0.17260930018973533
# time_since_restore: 31.367645740509033
# time_this_iter_s: 6.0261547565460205
# time_total_s: 31.367645740509033
# timers:
#   learn_throughput: 8685.152
#   learn_time_ms: 3.684
#   load_throughput: 122595.659
#   load_time_ms: 0.261
#   update_time_ms: 2.636
# timestamp: 1641931143
# timesteps_since_restore: 0
# timesteps_this_iter: 0
# timesteps_total: 6000
# training_iteration: 6
# trial_id: default
#
# agent_timesteps_total: 7000
# custom_metrics: {}
# date: 2022-01-11_19-59-09
# done: false
# episode_len_mean: 48.92
# episode_media: {}
# episode_reward_max: 167.0
# episode_reward_mean: 48.92
# episode_reward_min: 9.0
# episodes_this_iter: 10
# episodes_total: 202
# experiment_id: b244bf13b9b945709ab62fc7ab5c0c02
# hostname: run-61ddddeb0bbd833830273b3e-4dg5f
# info:
#   last_target_update_ts: 6544
#   learner:
#     default_policy:
#       custom_metrics: {}
#       learner_stats:
#         cur_lr: 0.0005000000237487257
#         max_q: 14.5231351852417
#         mean_q: 11.120903015136719
#         mean_td_error: -0.1007443517446518
#         min_q: -0.022861003875732422
#         model: {}
#       td_error:
#       - 0.8322210311889648
#       - 0.511042594909668
#       - 0.6259231567382812
#       - 0.06149864196777344
#       - 0.1014404296875
#       - -0.7538728713989258
#       - -1.1307344436645508
#       - 0.05668830871582031
#       - -0.1483907699584961
#       - -0.3962516784667969
#       - 0.9315304756164551
#       - -0.2667865753173828
#       - 0.43254852294921875
#       - -0.38956546783447266
#       - -0.763310432434082
#       - -1.0228610038757324
#       - 0.5499820709228516
#       - 0.3137493133544922
#       - -0.08421611785888672
#       - 0.09045219421386719
#       - 0.39658260345458984
#       - 0.7430300712585449
#       - -0.6879348754882812
#       - -0.5476865768432617
#       - -0.3571805953979492
#       - -1.7615089416503906
#       - -0.127044677734375
#       - -0.26493263244628906
#       - 0.1085195541381836
#       - -0.11568450927734375
#       - -0.4164094924926758
#       - 0.2553434371948242
#   num_agent_steps_sampled: 7000
#   num_agent_steps_trained: 48032
#   num_steps_sampled: 7000
#   num_steps_trained: 48032
#   num_steps_trained_this_iter: 0
#   num_target_updates: 12
# iterations_since_restore: 7
# node_ip: 10.0.47.167
# num_healthy_workers: 1
# off_policy_estimator: {}
# perf:
#   cpu_util_percent: 23.85
#   ram_util_percent: 14.9
# pid: 632
# policy_reward_max: {}
# policy_reward_mean: {}
# policy_reward_min: {}
# sampler_perf:
#   mean_action_processing_ms: 0.07764970844588788
#   mean_env_render_ms: 0.0
#   mean_env_wait_ms: 0.07937625207375991
#   mean_inference_ms: 1.1678334051893424
#   mean_raw_obs_processing_ms: 0.17173536614767052
# time_since_restore: 37.11836242675781
# time_this_iter_s: 5.750716686248779
# time_total_s: 37.11836242675781
# timers:
#   learn_throughput: 9514.332
#   learn_time_ms: 3.363
#   load_throughput: 128721.327
#   load_time_ms: 0.249
#   update_time_ms: 2.455
# timestamp: 1641931149
# timesteps_since_restore: 0
# timesteps_this_iter: 0
# timesteps_total: 7000
# training_iteration: 7
# trial_id: default
#
# agent_timesteps_total: 8000
# custom_metrics: {}
# date: 2022-01-11_19-59-15
# done: false
# episode_len_mean: 57.27
# episode_media: {}
# episode_reward_max: 200.0
# episode_reward_mean: 57.27
# episode_reward_min: 9.0
# episodes_this_iter: 7
# episodes_total: 209
# experiment_id: b244bf13b9b945709ab62fc7ab5c0c02
# hostname: run-61ddddeb0bbd833830273b3e-4dg5f
# info:
#   last_target_update_ts: 7552
#   learner:
#     default_policy:
#       custom_metrics: {}
#       learner_stats:
#         cur_lr: 0.0005000000237487257
#         max_q: 15.395959854125977
#         mean_q: 12.645805358886719
#         mean_td_error: 0.9742021560668945
#         min_q: 0.6217525005340576
#         model: {}
#       td_error:
#       - 0.7623186111450195
#       - 0.44716644287109375
#       - -0.046652793884277344
#       - 1.3809404373168945
#       - -0.4510984420776367
#       - 5.538997650146484
#       - 0.3379325866699219
#       - -0.047326087951660156
#       - -0.08164787292480469
#       - -1.0544548034667969
#       - -0.06081104278564453
#       - 0.3725309371948242
#       - 10.405420303344727
#       - -0.22460156679153442
#       - -0.45078277587890625
#       - 0.14220237731933594
#       - 11.657828330993652
#       - -0.4482903480529785
#       - 0.5081825256347656
#       - -0.9691324234008789
#       - -0.8862667083740234
#       - 0.7754688262939453
#       - 0.1085214614868164
#       - 0.9225530624389648
#       - 0.05618000030517578
#       - 0.4736785888671875
#       - 0.8975229263305664
#       - 0.06686687469482422
#       - 0.4419231414794922
#       - -0.2184772491455078
#       - 0.19406890869140625
#       - 0.6237077713012695
#   num_agent_steps_sampled: 8000
#   num_agent_steps_trained: 56032
#   num_steps_sampled: 8000
#   num_steps_trained: 56032
#   num_steps_trained_this_iter: 0
#   num_target_updates: 14
# iterations_since_restore: 8
# node_ip: 10.0.47.167
# num_healthy_workers: 1
# off_policy_estimator: {}
# perf:
#   cpu_util_percent: 23.25
#   ram_util_percent: 14.912500000000001
# pid: 632
# policy_reward_max: {}
# policy_reward_mean: {}
# policy_reward_min: {}
# sampler_perf:
#   mean_action_processing_ms: 0.07764267767501566
#   mean_env_render_ms: 0.0
#   mean_env_wait_ms: 0.07939248707447052
#   mean_inference_ms: 1.1671017493189375
#   mean_raw_obs_processing_ms: 0.1711335203458117
# time_since_restore: 42.791940689086914
# time_this_iter_s: 5.673578262329102
# time_total_s: 42.791940689086914
# timers:
#   learn_throughput: 8616.349
#   learn_time_ms: 3.714
#   load_throughput: 130778.26
#   load_time_ms: 0.245
#   update_time_ms: 2.561
# timestamp: 1641931155
# timesteps_since_restore: 0
# timesteps_this_iter: 0
# timesteps_total: 8000
# training_iteration: 8
# trial_id: default
# agent_timesteps_total: 9000
# custom_metrics: {}
# date: 2022-01-11_19-59-20
# done: false
# episode_len_mean: 66.12
# episode_media: {}
# episode_reward_max: 200.0
# episode_reward_mean: 66.12
# episode_reward_min: 10.0
# episodes_this_iter: 7
# episodes_total: 216
# experiment_id: b244bf13b9b945709ab62fc7ab5c0c02
# hostname: run-61ddddeb0bbd833830273b3e-4dg5f
# info:
#   last_target_update_ts: 8560
#   learner:
#     default_policy:
#       custom_metrics: {}
#       learner_stats:
#         cur_lr: 0.0005000000237487257
#         max_q: 18.246471405029297
#         mean_q: 12.826059341430664
#         mean_td_error: -0.209104523062706
#         min_q: -1.1964569091796875
#         model: {}
#       td_error:
#       - -0.4828033447265625
#       - 0.27493858337402344
#       - -0.4586048126220703
#       - 1.6203765869140625
#       - -0.5620698928833008
#       - -0.1281280517578125
#       - 0.4418964385986328
#       - -0.6010646820068359
#       - -2.1964569091796875
#       - -0.9463610649108887
#       - 0.594120979309082
#       - -0.21522140502929688
#       - 0.41666412353515625
#       - -0.33758544921875
#       - -0.045322418212890625
#       - 0.18645572662353516
#       - 0.005863189697265625
#       - 0.32310807704925537
#       - -0.19081878662109375
#       - 0.5574378967285156
#       - -0.12540340423583984
#       - -1.3040590286254883
#       - -1.5234007835388184
#       - -0.47388744354248047
#       - -0.9110870361328125
#       - -0.587855339050293
#       - -1.615468978881836
#       - 0.20021629333496094
#       - 0.3903169631958008
#       - 0.15434837341308594
#       - 0.4382972717285156
#       - 0.4102134704589844
#   num_agent_steps_sampled: 9000
#   num_agent_steps_trained: 64032
#   num_steps_sampled: 9000
#   num_steps_trained: 64032
#   num_steps_trained_this_iter: 0
#   num_target_updates: 16
# iterations_since_restore: 9
# node_ip: 10.0.47.167
# num_healthy_workers: 1
# off_policy_estimator: {}
# perf:
#   cpu_util_percent: 23.512500000000003
#   ram_util_percent: 14.95
# pid: 632
# policy_reward_max: {}
# policy_reward_mean: {}
# policy_reward_min: {}
# sampler_perf:
#   mean_action_processing_ms: 0.07763177903452652
#   mean_env_render_ms: 0.0
#   mean_env_wait_ms: 0.07940477727770866
#   mean_inference_ms: 1.1663223194074401
#   mean_raw_obs_processing_ms: 0.17045282658716235
# time_since_restore: 48.45015215873718
# time_this_iter_s: 5.6582114696502686
# time_total_s: 48.45015215873718
# timers:
#   learn_throughput: 8779.573
#   learn_time_ms: 3.645
#   load_throughput: 117343.703
#   load_time_ms: 0.273
#   update_time_ms: 2.619
# timestamp: 1641931160
# timesteps_since_restore: 0
# timesteps_this_iter: 0
# timesteps_total: 9000
# training_iteration: 9
# trial_id: default
#
# agent_timesteps_total: 10000
# custom_metrics: {}
# date: 2022-01-11_19-59-26
# done: false
# episode_len_mean: 74.44
# episode_media: {}
# episode_reward_max: 200.0
# episode_reward_mean: 74.44
# episode_reward_min: 10.0
# episodes_this_iter: 7
# episodes_total: 223
# experiment_id: b244bf13b9b945709ab62fc7ab5c0c02
# hostname: run-61ddddeb0bbd833830273b3e-4dg5f
# info:
#   last_target_update_ts: 9568
#   learner:
#     default_policy:
#       custom_metrics: {}
#       learner_stats:
#         cur_lr: 0.0005000000237487257
#         max_q: 19.70901107788086
#         mean_q: 15.719871520996094
#         mean_td_error: 0.677640438079834
#         min_q: -2.378023147583008
#         model: {}
#       td_error:
#       - 0.23376083374023438
#       - 0.9604816436767578
#       - 9.622905731201172
#       - 0.039714813232421875
#       - 0.2304401397705078
#       - 0.014545440673828125
#       - 0.14394760131835938
#       - 0.30573463439941406
#       - -3.378023147583008
#       - 0.13643264770507812
#       - 0.06982231140136719
#       - -3.1821727752685547
#       - -0.4752006530761719
#       - 0.04253196716308594
#       - 0.3107147216796875
#       - 0.0790252685546875
#       - 0.18435096740722656
#       - 0.15758514404296875
#       - 0.1540241241455078
#       - 7.030059814453125
#       - -0.8285560607910156
#       - 0.5175857543945312
#       - 0.7425441741943359
#       - 7.705844879150391
#       - 0.34461402893066406
#       - -0.10987472534179688
#       - 0.5160484313964844
#       - -1.1129474639892578
#       - -0.021722793579101562
#       - 0.8419971466064453
#       - 0.29768943786621094
#       - 0.11058998107910156
#   num_agent_steps_sampled: 10000
#   num_agent_steps_trained: 72032
#   num_steps_sampled: 10000
#   num_steps_trained: 72032
#   num_steps_trained_this_iter: 0
#   num_target_updates: 18
# iterations_since_restore: 10
# node_ip: 10.0.47.167
# num_healthy_workers: 1
# off_policy_estimator: {}
# perf:
#   cpu_util_percent: 23.6
#   ram_util_percent: 15.0
# pid: 632
# policy_reward_max: {}
# policy_reward_mean: {}
# policy_reward_min: {}
# sampler_perf:
#   mean_action_processing_ms: 0.07761723032285608
#   mean_env_render_ms: 0.0
#   mean_env_wait_ms: 0.07941155693923746
#   mean_inference_ms: 1.1654636160647556
#   mean_raw_obs_processing_ms: 0.1697189519894475
# time_since_restore: 54.132829666137695
# time_this_iter_s: 5.682677507400513
# time_total_s: 54.132829666137695
# timers:
#   learn_throughput: 9160.807
#   learn_time_ms: 3.493
#   load_throughput: 129616.348
#   load_time_ms: 0.247
#   update_time_ms: 2.517
# timestamp: 1641931166
# timesteps_since_restore: 0
# timesteps_this_iter: 0
# timesteps_total: 10000
# training_iteration: 10
# trial_id: default

# %% [markdown]
# #### Looking at the Results
#
# Let's take a look at the results of our training.  Which

# %%
#print path to logs

# !ls ~/ray_results/
# Out:
# DQN_CartPole-v0_2022-01-11_19-58-24rg2tyl6a

# %%
logs_path = input('Choose the log file>')
# Out:
# Choose the log file>DQN_CartPole-v0_2022-01-11_19-58-24rg2tyl6a

# %%
import pandas as pd

# choose the path to your output logs
logs_path = logs_path
data_path = '~/ray_results/{}/progress.csv'.format(logs_path)
graph_file = 'progress.csv'

df = pd.read_csv(data_path)
df.head()
# Out:
#    episode_reward_max  episode_reward_min  episode_reward_mean  \
# 0                53.0                 9.0            21.888889
# 1                53.0                 9.0            20.091837
# 2                78.0                 9.0            21.210000
# 3                80.0                 9.0            26.070000
# 4               137.0                 9.0            32.670000
#
#    episode_len_mean  episodes_this_iter  num_healthy_workers  timesteps_total  \
# 0         21.888889                  45                    1             1000
# 1         20.091837                  53                    1             2000
# 2         21.210000                  40                    1             3000
# 3         26.070000                  26                    1             4000
# 4         32.670000                  15                    1             5000
#
#    timesteps_this_iter  agent_timesteps_total   done  ...  \
# 0                    0                   1000  False  ...
# 1                    0                   2000  False  ...
# 2                    0                   3000  False  ...
# 3                    0                   4000  False  ...
# 4                    0                   5000  False  ...
#
#    info/last_target_update_ts  info/num_target_updates perf/cpu_util_percent  \
# 0                        1000                        1                16.025
# 1                        1504                        2                22.550
# 2                        2512                        4                23.300
# 3                        3520                        6                23.225
# 4                        4528                        8                22.950
#
#   perf/ram_util_percent               info/learner/default_policy/td_error  \
# 0               14.7000  [-1.0691776  -0.2270276  -0.61742437 -1.017636...
# 1               14.7625  [ 0.06405282  0.07242775 -0.0992837   0.354320...
# 2               14.8000  [-0.05341959 -1.2080201   2.5260353  -0.188503...
# 3               14.8000  [-1.5071988   0.16314983  0.2651515  -0.323109...
# 4               14.8125  [-0.0106039  -0.36222452 -1.2302375   0.054495...
#
#    info/learner/default_policy/learner_stats/cur_lr  \
# 0                                            0.0005
# 1                                            0.0005
# 2                                            0.0005
# 3                                            0.0005
# 4                                            0.0005
#
#    info/learner/default_policy/learner_stats/mean_q  \
# 0                                          0.021092
# 1                                          2.511995
# 2                                          3.812287
# 3                                          5.897418
# 4                                          7.446835
#
#    info/learner/default_policy/learner_stats/min_q  \
# 0                                        -0.608496
# 1                                         1.954679
# 2                                         1.533469
# 3                                         1.211725
# 4                                         0.637776
#
#    info/learner/default_policy/learner_stats/max_q  \
# 0                                         0.974688
# 1                                         3.663027
# 2                                         5.235931
# 3                                         7.757925
# 4                                         9.411139
#
#   info/learner/default_policy/learner_stats/mean_td_error
# 0                                          -0.628804
# 1                                           0.117307
# 2                                           0.274294
# 3                                          -0.105739
# 4                                           0.036506
#
# [5 rows x 50 columns]

# %%
## create dataframe with pertinent information and graph the episode reward mean against the episode  per iteration

episodes_this_iter = df['episodes_this_iter']
episodes_total = df['episodes_total']
episodes_reward_mean = df['episode_reward_mean']
episodes_reward_max = df['episode_reward_max']
episodes_reward_min = df['episode_reward_min']

df_episodes = pd.DataFrame(episodes_total)
df_episodes['episodes_reward_mean'] = df['episode_reward_mean']
df_episodes["episodes_reward_min"] = df['episode_reward_min']
df_episodes["episodes_reward_max"] = df['episode_reward_max']

df_episodes.plot.line()

## here we see the total number of episodes has increased overall but in each iteration, fewer episodes are required 
## to achieve a higher reward.  We see the algorithm learning more quickly towards the end when it reaches its maximum
## iterations and thus its best rewards.
# Out:
# <AxesSubplot:>

# %%
import pprint as pp

policy = trainer.get_policy()
model = policy.model
pp.pprint(model.model_config)
# Out:
# {'_disable_preprocessor_api': False,
#  '_time_major': False,
#  '_use_default_native_models': False,
#  'attention_dim': 64,
#  'attention_head_dim': 32,
#  'attention_init_gru_gate_bias': 2.0,
#  'attention_memory_inference': 50,
#  'attention_memory_training': 50,
#  'attention_num_heads': 1,
#  'attention_num_transformer_units': 1,
#  'attention_position_wise_mlp_dim': 32,
#  'attention_use_n_prev_actions': 0,
#  'attention_use_n_prev_rewards': 0,
#  'conv_activation': 'relu',
#  'conv_filters': None,
#  'custom_action_dist': None,
#  'custom_model': None,
#  'custom_model_config': {},
#  'custom_preprocessor': None,
#  'dim': 84,
#  'fcnet_activation': 'tanh',
#  'fcnet_hiddens': [256, 256],
#  'framestack': True,
#  'free_log_std': False,
#  'grayscale': False,
#  'lstm_cell_size': 256,
#  'lstm_use_prev_action': False,
#  'lstm_use_prev_action_reward': -1,
#  'lstm_use_prev_reward': False,
#  'max_seq_len': 20,
#  'no_final_linear': True,
#  'post_fcnet_activation': 'relu',
#  'post_fcnet_hiddens': [],
#  'use_attention': False,
#  'use_lstm': False,
#  'vf_share_layers': True,
#  'zero_mean': True}

# %%
ray.shutdown()

# %% [markdown]
# ### Creating a Custom Environment and Optimized Hyperparameters

# %%
if ray.is_initialized() == False:
   service_host = os.environ["RAY_HEAD_SERVICE_HOST"]
   service_port = os.environ["RAY_HEAD_SERVICE_PORT"]
   _temp_dir='/domino/datasets/local/{}/'.format(os.environ['DOMINO_PROJECT_NAME']) #set to a dataset
   ray.util.connect(f"{service_host}:{service_port}")

# %%
### Creating a custom environment; adapted from Ray documentation

"""Example of a custom gym environment and model. Run this for a demo.

This example shows:
  - using a custom environment
  - using a custom model
  - using Tune for grid search

You can visualize experiment results in ~/ray_results using TensorBoard.
"""
#ray.shutdown()
#ray.init()

import argparse
import gym
from gym.spaces import Discrete, Box
import numpy as np
import os
import random

import ray
from ray import tune
from ray.tune import grid_search
from ray.rllib.env.env_context import EnvContext
from ray.rllib.models import ModelCatalog
from ray.rllib.models.tf.tf_modelv2 import TFModelV2
from ray.rllib.models.tf.fcnet import FullyConnectedNetwork
from ray.rllib.models.torch.torch_modelv2 import TorchModelV2
from ray.rllib.models.torch.fcnet import FullyConnectedNetwork as TorchFC
from ray.rllib.utils.framework import try_import_tf, try_import_torch
from ray.rllib.utils.test_utils import check_learning_achieved

torch, nn = try_import_torch()
run = 'DQN'
framework = 'torch'
as_test="store_true"
stop_iters = 50
stop_timesteps = 100000
stop_reward = 0.1

class SimpleCorridor(gym.Env):
    """Example of a custom env in which you have to walk down a corridor.

    You can configure the length of the corridor via the env config."""

    def __init__(self, config: EnvContext):
        self.end_pos = config["corridor_length"]
        self.cur_pos = 0
        self.action_space = Discrete(2)
        self.observation_space = Box(
            0.0, self.end_pos, shape=(1, ), dtype=np.float32)
        # Set the seed. This is only used for the final (reach goal) reward.
        self.seed(config.worker_index * config.num_workers)

    def reset(self):
        self.cur_pos = 0
        return [self.cur_pos]

    def step(self, action):
        assert action in [0, 1], action
        if action == 0 and self.cur_pos > 0:
            self.cur_pos -= 1
        elif action == 1:
            self.cur_pos += 1
        done = self.cur_pos >= self.end_pos
        # Produce a random reward when we reach the goal.
        return [self.cur_pos], \
            random.random() * 2 if done else -0.1, done, {}

    def seed(self, seed=None):
        random.seed(seed)

class TorchCustomModel(TorchModelV2, nn.Module):
    """Example of a PyTorch custom model that just delegates to a fc-net."""

    def __init__(self, obs_space, action_space, num_outputs, model_config,
                 name):
        TorchModelV2.__init__(self, obs_space, action_space, num_outputs,
                              model_config, name)
        nn.Module.__init__(self)

        self.torch_sub_model = TorchFC(obs_space, action_space, num_outputs,
                                       model_config, name)

    def forward(self, input_dict, state, seq_lens):
        input_dict["obs"] = input_dict["obs"].float()
        fc_out, _ = self.torch_sub_model(input_dict, state, seq_lens)
        return fc_out, []

    def value_function(self):
        return torch.reshape(self.torch_sub_model.value_function(), [-1])

# %%
## run and create the environment; change to work in a notebook

import ray
from ray.tune import grid_search
import argparse
import gym
from gym.spaces import Discrete, Box
import numpy as np
import os
import random
import pprint as pp

import ray
from ray import tune
from ray.tune import grid_search
from ray.rllib.env.env_context import EnvContext
from ray.rllib.models import ModelCatalog
from ray.rllib.models.tf.tf_modelv2 import TFModelV2
from ray.rllib.models.tf.fcnet import FullyConnectedNetwork
from ray.rllib.models.torch.torch_modelv2 import TorchModelV2
from ray.rllib.models.torch.fcnet import FullyConnectedNetwork as TorchFC
from ray.rllib.utils.framework import try_import_tf, try_import_torch
from ray.rllib.utils.test_utils import check_learning_achieved
from ray.rllib.utils.numpy import convert_to_numpy

local_dir = '/domino/datasets/local/{}'.format(os.environ['DOMINO_PROJECT_NAME'])

# Can also register the env creator function explicitly with:
#. register_env("corridor", lambda config: SimpleCorridor(config))

ModelCatalog.register_custom_model(
    "my_model", TorchCustomModel
    if framework == "torch" else CustomModel)

config = {
    "env": SimpleCorridor,  # or "corridor" if registered above
    "env_config": {
        "corridor_length": 5,
    },
    # Ray will automatically detect the number of gpus if set to 0
    # Can be set manually if change '0' to and integer number below
    # The number will be Workers/GPUs requested - 1
    "num_gpus": 0,
    "model": {
        "custom_model": "my_model",
        "vf_share_layers": True,
    },
    "lr": grid_search([1e-2, 1e-4, 1e-6]),  # try different lrs
    "num_workers": 0,  # parallelism
    "framework": framework,
    'simple_optimizer': False
}

stop = {
    "training_iteration": stop_iters,
    "timesteps_total": stop_timesteps,
    "episode_reward_mean": stop_reward,
}

results = tune.run(run, config=config, stop=stop, local_dir = local_dir)

if as_test:
    check_learning_achieved(results, stop_reward)
    
print("best config: ", results.get_best_config(metric = 'episode_reward_mean', mode = 'max'))
# Out:
# (run pid=1119) == Status ==
# (run pid=1119) Current time: 2022-01-11 20:04:39 (running for 00:02:05.72)
# (run pid=1119) Memory usage on this node: 3.9/31.4 GiB
# (run pid=1119) Using FIFO scheduling algorithm.
# (run pid=1119) Resources requested: 0/30 CPUs, 0/0 GPUs, 0.0/91.6 GiB heap, 0.0/40.41 GiB objects
# (run pid=1119) Result logdir: /domino/datasets/local/Ray_Quick_Start/DQN
# (run pid=1119) Number of trials: 3/3 (3 PENDING)
# (run pid=1119) +--------------------------------+----------+-------+--------+
# (run pid=1119) | Trial name                     | status   | loc   |     lr |
# (run pid=1119) |--------------------------------+----------+-------+--------|
# (run pid=1119) | DQN_SimpleCorridor_6a7de_00000 | PENDING  |       | 0.01   |
# (run pid=1119) | DQN_SimpleCorridor_6a7de_00001 | PENDING  |       | 0.0001 |
# (run pid=1119) | DQN_SimpleCorridor_6a7de_00002 | PENDING  |       | 1e-06  |
# (run pid=1119) +--------------------------------+----------+-------+--------+
# (run pid=1119)
# (run pid=1119)
# (run pid=1118) == Status ==
# (run pid=1118) Current time: 2022-01-11 20:04:43 (running for 00:00:00.19)
# (run pid=1118) Memory usage on this node: 4.1/31.4 GiB
# (run pid=1118) Using FIFO scheduling algorithm.
# (run pid=1118) Resources requested: 0/30 CPUs, 0/0 GPUs, 0.0/91.6 GiB heap, 0.0/40.41 GiB objects
# (run pid=1118) Result logdir: /domino/datasets/local/Ray_Quick_Start/DQN
# (run pid=1118) Number of trials: 3/3 (3 PENDING)
# (run pid=1118) +--------------------------------+----------+-------+--------+
# (run pid=1118) | Trial name                     | status   | loc   |     lr |
# (run pid=1118) |--------------------------------+----------+-------+--------|
# (run pid=1118) | DQN_SimpleCorridor_b7640_00000 | PENDING  |       | 0.01   |
# (run pid=1118) | DQN_SimpleCorridor_b7640_00001 | PENDING  |       | 0.0001 |
# (run pid=1118) | DQN_SimpleCorridor_b7640_00002 | PENDING  |       | 1e-06  |
# (run pid=1118) +--------------------------------+----------+-------+--------+
# (run pid=1118)
# (run pid=1118)
# (run pid=1119) == Status ==
# (run pid=1119) Current time: 2022-01-11 20:04:44 (running for 00:02:10.75)
# (run pid=1119) Memory usage on this node: 4.2/31.4 GiB
# (run pid=1119) Using FIFO scheduling algorithm.
# (run pid=1119) Resources requested: 0/30 CPUs, 0/0 GPUs, 0.0/91.6 GiB heap, 0.0/40.41 GiB objects
# (run pid=1119) Result logdir: /domino/datasets/local/Ray_Quick_Start/DQN
# (run pid=1119) Number of trials: 3/3 (3 PENDING)
# (run pid=1119) +--------------------------------+----------+-------+--------+
# (run pid=1119) | Trial name                     | status   | loc   |     lr |
# (run pid=1119) |--------------------------------+----------+-------+--------|
# (run pid=1119) | DQN_SimpleCorridor_6a7de_00000 | PENDING  |       | 0.01   |
# (run pid=1119) | DQN_SimpleCorridor_6a7de_00001 | PENDING  |       | 0.0001 |
# (run pid=1119) | DQN_SimpleCorridor_6a7de_00002 | PENDING  |       | 1e-06  |
# (run pid=1119) +--------------------------------+----------+-------+--------+
# (run pid=1119)
# (run pid=1119)
# (DQN pid=365, ip=10.0.45.20) 2022-01-11 20:04:47,848	WARNING deprecation.py:45 -- DeprecationWarning: `simple_optimizer` has been deprecated. This will raise an error in the future!
# (DQN pid=365, ip=10.0.45.20) 2022-01-11 20:04:47,848	INFO dqn.py:141 -- In multi-agent mode, policies will be optimized sequentially by the multi-GPU optimizer. Consider setting simple_optimizer=True if this doesn't work for you.
# (DQN pid=365, ip=10.0.45.20) 2022-01-11 20:04:47,848	INFO trainer.py:743 -- Current log_level is WARN. For more information, set 'log_level': 'INFO' / 'DEBUG' or use the -v and -vv flags.
# (DQN pid=365, ip=10.0.45.20) 2022-01-11 20:04:47,874	WARNING deprecation.py:45 -- DeprecationWarning: `convert_to_non_torch_type` has been deprecated. Use `ray/rllib/utils/numpy.py::convert_to_numpy` instead. This will raise an error in the future!
# (DQN pid=365, ip=10.0.35.140) 2022-01-11 20:04:47,913	WARNING deprecation.py:45 -- DeprecationWarning: `simple_optimizer` has been deprecated. This will raise an error in the future!
# (DQN pid=365, ip=10.0.35.140) 2022-01-11 20:04:47,913	INFO dqn.py:141 -- In multi-agent mode, policies will be optimized sequentially by the multi-GPU optimizer. Consider setting simple_optimizer=True if this doesn't work for you.
# (DQN pid=365, ip=10.0.35.140) 2022-01-11 20:04:47,913	INFO trainer.py:743 -- Current log_level is WARN. For more information, set 'log_level': 'INFO' / 'DEBUG' or use the -v and -vv flags.
# (DQN pid=365, ip=10.0.35.140) 2022-01-11 20:04:47,940	WARNING deprecation.py:45 -- DeprecationWarning: `convert_to_non_torch_type` has been deprecated. Use `ray/rllib/utils/numpy.py::convert_to_numpy` instead. This will raise an error in the future!
# (DQN pid=240, ip=10.0.60.133) 2022-01-11 20:04:48,153	WARNING deprecation.py:45 -- DeprecationWarning: `simple_optimizer` has been deprecated. This will raise an error in the future!
# (DQN pid=240, ip=10.0.60.133) 2022-01-11 20:04:48,153	INFO dqn.py:141 -- In multi-agent mode, policies will be optimized sequentially by the multi-GPU optimizer. Consider setting simple_optimizer=True if this doesn't work for you.
# (DQN pid=240, ip=10.0.60.133) 2022-01-11 20:04:48,153	INFO trainer.py:743 -- Current log_level is WARN. For more information, set 'log_level': 'INFO' / 'DEBUG' or use the -v and -vv flags.
# (DQN pid=240, ip=10.0.60.133) 2022-01-11 20:04:48,180	WARNING deprecation.py:45 -- DeprecationWarning: `convert_to_non_torch_type` has been deprecated. Use `ray/rllib/utils/numpy.py::convert_to_numpy` instead. This will raise an error in the future!
# (run pid=1118) == Status ==
# (run pid=1118) Current time: 2022-01-11 20:04:48 (running for 00:00:05.52)
# (run pid=1118) Memory usage on this node: 4.2/31.4 GiB
# (run pid=1118) Using FIFO scheduling algorithm.
# (run pid=1118) Resources requested: 3.0/30 CPUs, 0/0 GPUs, 0.0/91.6 GiB heap, 0.0/40.41 GiB objects
# (run pid=1118) Result logdir: /domino/datasets/local/Ray_Quick_Start/DQN
# (run pid=1118) Number of trials: 3/3 (3 RUNNING)
# (run pid=1118) +--------------------------------+----------+-----------------+--------+
# (run pid=1118) | Trial name                     | status   | loc             |     lr |
# (run pid=1118) |--------------------------------+----------+-----------------+--------|
# (run pid=1118) | DQN_SimpleCorridor_b7640_00000 | RUNNING  | 10.0.60.133:240 | 0.01   |
# (run pid=1118) | DQN_SimpleCorridor_b7640_00001 | RUNNING  | 10.0.35.140:365 | 0.0001 |
# (run pid=1118) | DQN_SimpleCorridor_b7640_00002 | RUNNING  | 10.0.45.20:365  | 1e-06  |
# (run pid=1118) +--------------------------------+----------+-----------------+--------+
# (run pid=1118)
# (run pid=1118)
# (run pid=1119) == Status ==
# (run pid=1119) Current time: 2022-01-11 20:04:49 (running for 00:02:15.75)
# (run pid=1119) Memory usage on this node: 4.2/31.4 GiB
# (run pid=1119) Using FIFO scheduling algorithm.
# (run pid=1119) Resources requested: 0/30 CPUs, 0/0 GPUs, 0.0/91.6 GiB heap, 0.0/40.41 GiB objects
# (run pid=1119) Result logdir: /domino/datasets/local/Ray_Quick_Start/DQN
# (run pid=1119) Number of trials: 3/3 (3 PENDING)
# (run pid=1119) +--------------------------------+----------+-------+--------+
# (run pid=1119) | Trial name                     | status   | loc   |     lr |
# (run pid=1119) |--------------------------------+----------+-------+--------|
# (run pid=1119) | DQN_SimpleCorridor_6a7de_00000 | PENDING  |       | 0.01   |
# (run pid=1119) | DQN_SimpleCorridor_6a7de_00001 | PENDING  |       | 0.0001 |
# (run pid=1119) | DQN_SimpleCorridor_6a7de_00002 | PENDING  |       | 1e-06  |
# (run pid=1119) +--------------------------------+----------+-------+--------+
# (run pid=1119)
# (run pid=1119)
# (run pid=1118) Result for DQN_SimpleCorridor_b7640_00002:
# (run pid=1118)   agent_timesteps_total: 1000
# (run pid=1118)   custom_metrics: {}
# (run pid=1118)   date: 2022-01-11_20-04-50
# (run pid=1118)   done: false
# (run pid=1118)   episode_len_mean: 21.822222222222223
# (run pid=1118)   episode_media: {}
# (run pid=1118)   episode_reward_max: 1.5649207710225146
# (run pid=1118)   episode_reward_mean: -0.931482114753388
# (run pid=1118)   episode_reward_min: -7.781546153105541
# (run pid=1118)   episodes_this_iter: 45
# (run pid=1118)   episodes_total: 45
# (run pid=1118)   experiment_id: bf4eb87322334aa5b212549c9412c3af
# (run pid=1118)   hostname: ray-61ddddeb0bbd833830273b3e-ray-worker-2
# (run pid=1118)   info:
# (run pid=1118)     last_target_update_ts: 1000
# (run pid=1118)     learner:
# (run pid=1118)       default_policy:
# (run pid=1118)         custom_metrics: {}
# (run pid=1118)         learner_stats:
# (run pid=1118)           allreduce_latency: 0.0
# (run pid=1118)           cur_lr: 1.0e-06
# (run pid=1118)           grad_gnorm: 1.8894556760787964
# (run pid=1118)           max_q: 1.017080307006836
# (run pid=1118)           mean_q: 0.5477238297462463
# (run pid=1118)           min_q: 0.0
# (run pid=1118)         mean_td_error: 0.008215726353228092
# (run pid=1118)         model: {}
# (run pid=1118)         td_error:
# (run pid=1118)         - 0.10872447490692139
# (run pid=1118)         - 0.09856057167053223
# (run pid=1118)         - 0.10000000149011612
# (run pid=1118)         - -0.800989031791687
# (run pid=1118)         - -0.800989031791687
# (run pid=1118)         - -0.800989031791687
# (run pid=1118)         - -0.800989031791687
# (run pid=1118)         - 0.016092121601104736
# (run pid=1118)         - 0.6896375417709351
# (run pid=1118)         - 0.10000000149011612
# (run pid=1118)         - 0.9976710081100464
# (run pid=1118)         - -0.800989031791687
# (run pid=1118)         - 0.10872447490692139
# (run pid=1118)         - 0.10000000149011612
# (run pid=1118)         - 0.6896375417709351
# (run pid=1118)         - 0.6896375417709351
# (run pid=1118)         - -0.800989031791687
# (run pid=1118)         - 0.10872447490692139
# (run pid=1118)         - 0.09856057167053223
# (run pid=1118)         - 0.016092121601104736
# (run pid=1118)         - 0.10872447490692139
# (run pid=1118)         - 0.6896375417709351
# (run pid=1118)         - 0.016092121601104736
# (run pid=1118)         - 0.10000000149011612
# (run pid=1118)         - -0.19235289096832275
# (run pid=1118)         - 0.10872447490692139
# (run pid=1118)         - 0.016092121601104736
# (run pid=1118)         - 0.6896375417709351
# (run pid=1118)         - -0.19235289096832275
# (run pid=1118)         - 0.10000000149011612
# (run pid=1118)         - -0.19235265254974365
# (run pid=1118)         - -0.10507482290267944
# (run pid=1118)     num_agent_steps_sampled: 1000
# (run pid=1118)     num_agent_steps_trained: 32
# (run pid=1118)     num_steps_sampled: 1000
# (run pid=1118)     num_steps_trained: 32
# (run pid=1118)     num_target_updates: 1
# (run pid=1118)   iterations_since_restore: 1
# (run pid=1118)   node_ip: 10.0.45.20
# (run pid=1118)   num_healthy_workers: 0
# (run pid=1118)   off_policy_estimator: {}
# (run pid=1118)   perf:
# (run pid=1118)     cpu_util_percent: 14.575
# (run pid=1118)     ram_util_percent: 10.6
# (run pid=1118)   pid: 365
# (run pid=1118)   policy_reward_max: {}
# (run pid=1118)   policy_reward_mean: {}
# (run pid=1118)   policy_reward_min: {}
# (run pid=1118)   sampler_perf:
# (run pid=1118)     mean_action_processing_ms: 0.06314781638649436
# (run pid=1118)     mean_env_render_ms: 0.0
# (run pid=1118)     mean_env_wait_ms: 0.050138164828945495
# (run pid=1118)     mean_inference_ms: 1.6314080664208843
# (run pid=1118)     mean_raw_obs_processing_ms: 0.18184192173488134
# (run pid=1118)   time_since_restore: 2.187708854675293
# (run pid=1118)   time_this_iter_s: 2.187708854675293
# (run pid=1118)   time_total_s: 2.187708854675293
# (run pid=1118)   timers:
# (run pid=1118)     learn_throughput: 2475.246
# (run pid=1118)     learn_time_ms: 12.928
# (run pid=1118)     load_throughput: 82291.679
# (run pid=1118)     load_time_ms: 0.389
# (run pid=1118)   timestamp: 1641931490
# (run pid=1118)   timesteps_since_restore: 0
# (run pid=1118)   timesteps_this_iter: 0
# (run pid=1118)   timesteps_total: 1000
# (run pid=1118)   training_iteration: 1
# (run pid=1118)   trial_id: b7640_00002
# (run pid=1118)
# (run pid=1118) Result for DQN_SimpleCorridor_b7640_00001:
# (run pid=1118)   agent_timesteps_total: 1000
# (run pid=1118)   custom_metrics: {}
# (run pid=1118)   date: 2022-01-11_20-04-50
# (run pid=1118)   done: false
# (run pid=1118)   episode_len_mean: 31.741935483870968
# (run pid=1118)   episode_media: {}
# (run pid=1118)   episode_reward_max: 0.9765775380267009
# (run pid=1118)   episode_reward_mean: -2.0002849483693663
# (run pid=1118)   episode_reward_min: -11.902361019422154
# (run pid=1118)   episodes_this_iter: 31
# (run pid=1118)   episodes_total: 31
# (run pid=1118)   experiment_id: 1701d7fc35984e78a6ec77d94b20b4e8
# (run pid=1118)   hostname: ray-61ddddeb0bbd833830273b3e-ray-worker-3
# (run pid=1118)   info:
# (run pid=1118)     last_target_update_ts: 1000
# (run pid=1118)     learner:
# (run pid=1118)       default_policy:
# (run pid=1118)         custom_metrics: {}
# (run pid=1118)         learner_stats:
# (run pid=1118)           allreduce_latency: 0.0
# (run pid=1118)           cur_lr: 0.0001
# (run pid=1118)           grad_gnorm: 1.0062036514282227
# (run pid=1118)           max_q: 0.581016480922699
# (run pid=1118)           mean_q: 0.16456486284732819
# (run pid=1118)           min_q: 0.0
# (run pid=1118)         mean_td_error: -0.1243211179971695
# (run pid=1118)         model: {}
# (run pid=1118)         td_error:
# (run pid=1118)         - -0.3345191180706024
# (run pid=1118)         - -1.0690240859985352
# (run pid=1118)         - -0.24033594131469727
# (run pid=1118)         - 0.10001451522111893
# (run pid=1118)         - -0.3345191180706024
# (run pid=1118)         - 0.10348889231681824
# (run pid=1118)         - 0.10001451522111893
# (run pid=1118)         - -0.24033594131469727
# (run pid=1118)         - 0.10001451522111893
# (run pid=1118)         - 0.10001451522111893
# (run pid=1118)         - 0.10000000149011612
# (run pid=1118)         - -0.3345191180706024
# (run pid=1118)         - 0.08784922957420349
# (run pid=1118)         - 0.10000000149011612
# (run pid=1118)         - 0.08784922957420349
# (run pid=1118)         - -0.3345191180706024
# (run pid=1118)         - -0.3345191180706024
# (run pid=1118)         - -0.016241788864135742
# (run pid=1118)         - -0.3345191180706024
# (run pid=1118)         - -0.3345191180706024
# (run pid=1118)         - 0.08784922957420349
# (run pid=1118)         - 0.08784922957420349
# (run pid=1118)         - 0.10001451522111893
# (run pid=1118)         - 0.10001451522111893
# (run pid=1118)         - -0.3345191180706024
# (run pid=1118)         - 0.10000000149011612
# (run pid=1118)         - 0.08784922957420349
# (run pid=1118)         - 0.10000000149011612
# (run pid=1118)         - -1.2386858463287354
# (run pid=1118)         - 0.10000000149011612
# (run pid=1118)         - -0.2403358519077301
# (run pid=1118)         - 0.1000145897269249
# (run pid=1118)     num_agent_steps_sampled: 1000
# (run pid=1118)     num_agent_steps_trained: 32
# (run pid=1118)     num_steps_sampled: 1000
# (run pid=1118)     num_steps_trained: 32
# (run pid=1118)     num_target_updates: 1
# (run pid=1118)   iterations_since_restore: 1
# (run pid=1118)   node_ip: 10.0.35.140
# (run pid=1118)   num_healthy_workers: 0
# (run pid=1118)   off_policy_estimator: {}
# (run pid=1118)   perf:
# (run pid=1118)     cpu_util_percent: 14.5
# (run pid=1118)     ram_util_percent: 10.5
# (run pid=1118)   pid: 365
# (run pid=1118)   policy_reward_max: {}
# (run pid=1118)   policy_reward_mean: {}
# (run pid=1118)   policy_reward_min: {}
# (run pid=1118)   sampler_perf:
# (run pid=1118)     mean_action_processing_ms: 0.06572254649647229
# (run pid=1118)     mean_env_render_ms: 0.0
# (run pid=1118)     mean_env_wait_ms: 0.050938212788188365
# (run pid=1118)     mean_inference_ms: 1.6533042286540365
# (run pid=1118)     mean_raw_obs_processing_ms: 0.18191623401927673
# (run pid=1118)   time_since_restore: 2.215313673019409
# (run pid=1118)   time_this_iter_s: 2.215313673019409
# (run pid=1118)   time_total_s: 2.215313673019409
# (run pid=1118)   timers:
# (run pid=1118)     learn_throughput: 2502.801
# (run pid=1118)     learn_time_ms: 12.786
# (run pid=1118)     load_throughput: 106861.248
# (run pid=1118)     load_time_ms: 0.299
# (run pid=1118)   timestamp: 1641931490
# (run pid=1118)   timesteps_since_restore: 0
# (run pid=1118)   timesteps_this_iter: 0
# (run pid=1118)   timesteps_total: 1000
# (run pid=1118)   training_iteration: 1
# (run pid=1118)   trial_id: b7640_00001
# (run pid=1118)
# (run pid=1118) Result for DQN_SimpleCorridor_b7640_00000:
# (run pid=1118)   agent_timesteps_total: 1000
# (run pid=1118)   custom_metrics: {}
# (run pid=1118)   date: 2022-01-11_20-04-50
# (run pid=1118)   done: false
# (run pid=1118)   episode_len_mean: 44.68181818181818
# (run pid=1118)   episode_media: {}
# (run pid=1118)   episode_reward_max: 0.893005108339992
# (run pid=1118)   episode_reward_mean: -3.2097288484383886
# (run pid=1118)   episode_reward_min: -19.21123530688687
# (run pid=1118)   episodes_this_iter: 22
# (run pid=1118)   episodes_total: 22
# (run pid=1118)   experiment_id: 5142525d048c4f86ac65025dd714721b
# (run pid=1118)   hostname: ray-61ddddeb0bbd833830273b3e-ray-worker-0
# (run pid=1118)   info:
# (run pid=1118)     last_target_update_ts: 1000
# (run pid=1118)     learner:
# (run pid=1118)       default_policy:
# (run pid=1118)         custom_metrics: {}
# (run pid=1118)         learner_stats:
# (run pid=1118)           allreduce_latency: 0.0
# (run pid=1118)           cur_lr: 0.01
# (run pid=1118)           grad_gnorm: 6.178723335266113
# (run pid=1118)           max_q: 1.2247374057769775
# (run pid=1118)           mean_q: 0.45638376474380493
# (run pid=1118)           min_q: 0.0
# (run pid=1118)         mean_td_error: -0.2922290563583374
# (run pid=1118)         model: {}
# (run pid=1118)         td_error:
# (run pid=1118)         - 0.10000000149011612
# (run pid=1118)         - -0.9391133785247803
# (run pid=1118)         - 0.2633812427520752
# (run pid=1118)         - -1.0193634033203125
# (run pid=1118)         - -0.9770216345787048
# (run pid=1118)         - 0.2633812427520752
# (run pid=1118)         - -1.0193634033203125
# (run pid=1118)         - 0.13180291652679443
# (run pid=1118)         - -0.9770216345787048
# (run pid=1118)         - -0.9391133785247803
# (run pid=1118)         - 1.1496095657348633
# (run pid=1118)         - 1.1496095657348633
# (run pid=1118)         - -0.9391133785247803
# (run pid=1118)         - -0.9391133785247803
# (run pid=1118)         - 1.1496095657348633
# (run pid=1118)         - -1.0193634033203125
# (run pid=1118)         - -0.9770216345787048
# (run pid=1118)         - -1.0193634033203125
# (run pid=1118)         - -0.9770216345787048
# (run pid=1118)         - 0.13180291652679443
# (run pid=1118)         - 1.1496095657348633
# (run pid=1118)         - -1.0193634033203125
# (run pid=1118)         - -0.9391133785247803
# (run pid=1118)         - -0.9391133785247803
# (run pid=1118)         - -1.0193634033203125
# (run pid=1118)         - -1.0193634033203125
# (run pid=1118)         - 0.10000000149011612
# (run pid=1118)         - 0.11468756198883057
# (run pid=1118)         - 1.1496095657348633
# (run pid=1118)         - -0.9391133785247803
# (run pid=1118)         - 1.1496089696884155
# (run pid=1118)         - 0.2633819580078125
# (run pid=1118)     num_agent_steps_sampled: 1000
# (run pid=1118)     num_agent_steps_trained: 32
# (run pid=1118)     num_steps_sampled: 1000
# (run pid=1118)     num_steps_trained: 32
# (run pid=1118)     num_target_updates: 1
# (run pid=1118)   iterations_since_restore: 1
# (run pid=1118)   node_ip: 10.0.60.133
# (run pid=1118)   num_healthy_workers: 0
# (run pid=1118)   off_policy_estimator: {}
# (run pid=1118)   perf:
# (run pid=1118)     cpu_util_percent: 15.300000000000002
# (run pid=1118)     ram_util_percent: 10.5
# (run pid=1118)   pid: 240
# (run pid=1118)   policy_reward_max: {}
# (run pid=1118)   policy_reward_mean: {}
# (run pid=1118)   policy_reward_min: {}
# (run pid=1118)   sampler_perf:
# (run pid=1118)     mean_action_processing_ms: 0.06063501318017919
# (run pid=1118)     mean_env_render_ms: 0.0
# (run pid=1118)     mean_env_wait_ms: 0.04902919689258496
# (run pid=1118)     mean_inference_ms: 1.5498355671123314
# (run pid=1118)     mean_raw_obs_processing_ms: 0.1676489899565766
# (run pid=1118)   time_since_restore: 2.0839626789093018
# (run pid=1118)   time_this_iter_s: 2.0839626789093018
# (run pid=1118)   time_total_s: 2.0839626789093018
# (run pid=1118)   timers:
# (run pid=1118)     learn_throughput: 2668.344
# (run pid=1118)     learn_time_ms: 11.992
# (run pid=1118)     load_throughput: 108502.61
# (run pid=1118)     load_time_ms: 0.295
# (run pid=1118)   timestamp: 1641931490
# (run pid=1118)   timesteps_since_restore: 0
# (run pid=1118)   timesteps_this_iter: 0
# (run pid=1118)   timesteps_total: 1000
# (run pid=1118)   training_iteration: 1
# (run pid=1118)   trial_id: b7640_00000
# (run pid=1118)
# (run pid=1118) == Status ==
# (run pid=1118) Current time: 2022-01-11 20:04:54 (running for 00:00:11.44)
# (run pid=1118) Memory usage on this node: 4.2/31.4 GiB
# (run pid=1118) Using FIFO scheduling algorithm.
# (run pid=1118) Resources requested: 3.0/30 CPUs, 0/0 GPUs, 0.0/91.6 GiB heap, 0.0/40.41 GiB objects
# (run pid=1118) Result logdir: /domino/datasets/local/Ray_Quick_Start/DQN
# (run pid=1118) Number of trials: 3/3 (3 RUNNING)
# (run pid=1118) +--------------------------------+----------+-----------------+--------+--------+------------------+------+-----------+----------------------+----------------------+--------------------+
# (run pid=1118) | Trial name                     | status   | loc             |     lr |   iter |   total time (s) |   ts |    reward |   episode_reward_max |   episode_reward_min |   episode_len_mean |
# (run pid=1118) |--------------------------------+----------+-----------------+--------+--------+------------------+------+-----------+----------------------+----------------------+--------------------|
# (run pid=1118) | DQN_SimpleCorridor_b7640_00000 | RUNNING  | 10.0.60.133:240 | 0.01   |      1 |          2.08396 | 1000 | -3.20973  |             0.893005 |            -19.2112  |            44.6818 |
# (run pid=1118) | DQN_SimpleCorridor_b7640_00001 | RUNNING  | 10.0.35.140:365 | 0.0001 |      1 |          2.21531 | 1000 | -2.00028  |             0.976578 |            -11.9024  |            31.7419 |
# (run pid=1118) | DQN_SimpleCorridor_b7640_00002 | RUNNING  | 10.0.45.20:365  | 1e-06  |      1 |          2.18771 | 1000 | -0.931482 |             1.56492  |             -7.78155 |            21.8222 |
# (run pid=1118) +--------------------------------+----------+-----------------+--------+--------+------------------+------+-----------+----------------------+----------------------+--------------------+
# (run pid=1118)
# (run pid=1118)
# (run pid=1119) == Status ==
# (run pid=1119) Current time: 2022-01-11 20:04:54 (running for 00:02:20.79)
# (run pid=1119) Memory usage on this node: 4.2/31.4 GiB
# (run pid=1119) Using FIFO scheduling algorithm.
# (run pid=1119) Resources requested: 0/30 CPUs, 0/0 GPUs, 0.0/91.6 GiB heap, 0.0/40.41 GiB objects
# (run pid=1119) Result logdir: /domino/datasets/local/Ray_Quick_Start/DQN
# (run pid=1119) Number of trials: 3/3 (3 PENDING)
# (run pid=1119) +--------------------------------+----------+-------+--------+
# (run pid=1119) | Trial name                     | status   | loc   |     lr |
# (run pid=1119) |--------------------------------+----------+-------+--------|
# (run pid=1119) | DQN_SimpleCorridor_6a7de_00000 | PENDING  |       | 0.01   |
# (run pid=1119) | DQN_SimpleCorridor_6a7de_00001 | PENDING  |       | 0.0001 |
# (run pid=1119) | DQN_SimpleCorridor_6a7de_00002 | PENDING  |       | 1e-06  |
# (run pid=1119) +--------------------------------+----------+-------+--------+
# (run pid=1119)
# (run pid=1119)
# (run pid=1118) Result for DQN_SimpleCorridor_b7640_00002:
# (run pid=1118)   agent_timesteps_total: 2000
# (run pid=1118)   custom_metrics: {}
# (run pid=1118)   date: 2022-01-11_20-04-55
# (run pid=1118)   done: false
# (run pid=1118)   episode_len_mean: 18.15
# (run pid=1118)   episode_media: {}
# (run pid=1118)   episode_reward_max: 1.2992416084362501
# (run pid=1118)   episode_reward_mean: -0.6386491429939937
# (run pid=1118)   episode_reward_min: -7.781546153105541
# (run pid=1118)   episodes_this_iter: 60
# (run pid=1118)   episodes_total: 105
# (run pid=1118)   experiment_id: bf4eb87322334aa5b212549c9412c3af
# (run pid=1118)   hostname: ray-61ddddeb0bbd833830273b3e-ray-worker-2
# (run pid=1118)   info:
# (run pid=1118)     last_target_update_ts: 1504
# (run pid=1118)     learner:
# (run pid=1118)       default_policy:
# (run pid=1118)         custom_metrics: {}
# (run pid=1118)         learner_stats:
# (run pid=1118)           allreduce_latency: 0.0
# (run pid=1118)           cur_lr: 1.0e-06
# (run pid=1118)           grad_gnorm: 0.05329073593020439
# (run pid=1118)           max_q: 0.9535636901855469
# (run pid=1118)           mean_q: 0.3483419716358185
# (run pid=1118)           min_q: 0.0005507187452167273
# (run pid=1118)         mean_td_error: -0.3142169117927551
# (run pid=1118)         model: {}
# (run pid=1118)         td_error:
# (run pid=1118)         - -0.7659747004508972
# (run pid=1118)         - -0.010502338409423828
# (run pid=1118)         - 0.48979973793029785
# (run pid=1118)         - 0.09768875688314438
# (run pid=1118)         - -0.7659747004508972
# (run pid=1118)         - -0.7659747004508972
# (run pid=1118)         - -0.7659747004508972
# (run pid=1118)         - 0.09768875688314438
# (run pid=1118)         - -0.2687907814979553
# (run pid=1118)         - -0.2687907814979553
# (run pid=1118)         - -0.7659747004508972
# (run pid=1118)         - -0.010502338409423828
# (run pid=1118)         - -0.7759897708892822
# (run pid=1118)         - -0.7659747004508972
# (run pid=1118)         - -1.0250424146652222
# (run pid=1118)         - 0.9534253478050232
# (run pid=1118)         - 0.07790040969848633
# (run pid=1118)         - -0.7659747004508972
# (run pid=1118)         - -0.7659747004508972
# (run pid=1118)         - 0.09768875688314438
# (run pid=1118)         - -0.7659747004508972
# (run pid=1118)         - 0.4405861496925354
# (run pid=1118)         - 0.06839418411254883
# (run pid=1118)         - 0.06839418411254883
# (run pid=1118)         - 0.48979973793029785
# (run pid=1118)         - -0.7659747004508972
# (run pid=1118)         - -0.7659747004508972
# (run pid=1118)         - -0.7659747004508972
# (run pid=1118)         - -0.7659747004508972
# (run pid=1118)         - 0.48979973793029785
# (run pid=1118)         - -0.3428418040275574
# (run pid=1118)         - -0.765974760055542
# (run pid=1118)     num_agent_steps_sampled: 2000
# (run pid=1118)     num_agent_steps_trained: 8032
# (run pid=1118)     num_steps_sampled: 2000
# (run pid=1118)     num_steps_trained: 8032
# (run pid=1118)     num_steps_trained_this_iter: 0
# (run pid=1118)     num_target_updates: 2
# (run pid=1118)   iterations_since_restore: 2
# (run pid=1118)   node_ip: 10.0.45.20
# (run pid=1118)   num_healthy_workers: 0
# (run pid=1118)   off_policy_estimator: {}
# (run pid=1118)   perf:
# (run pid=1118)     cpu_util_percent: 14.357142857142858
# (run pid=1118)     ram_util_percent: 10.700000000000001
# (run pid=1118)   pid: 365
# (run pid=1118)   policy_reward_max: {}
# (run pid=1118)   policy_reward_mean: {}
# (run pid=1118)   policy_reward_min: {}
# (run pid=1118)   sampler_perf:
# (run pid=1118)     mean_action_processing_ms: 0.06305622798862195
# (run pid=1118)     mean_env_render_ms: 0.0
# (run pid=1118)     mean_env_wait_ms: 0.050388614767719185
# (run pid=1118)     mean_inference_ms: 1.5940151414114079
# (run pid=1118)     mean_raw_obs_processing_ms: 0.18334082755014453
# (run pid=1118)   time_since_restore: 7.466257810592651
# (run pid=1118)   time_this_iter_s: 5.278548955917358
# (run pid=1118)   time_total_s: 7.466257810592651
# (run pid=1118)   timers:
# (run pid=1118)     learn_throughput: 3969.342
# (run pid=1118)     learn_time_ms: 8.062
# (run pid=1118)     load_throughput: 123169.43
# (run pid=1118)     load_time_ms: 0.26
# (run pid=1118)   timestamp: 1641931495
# (run pid=1118)   timesteps_since_restore: 0
# (run pid=1118)   timesteps_this_iter: 0
# (run pid=1118)   timesteps_total: 2000
# (run pid=1118)   training_iteration: 2
# (run pid=1118)   trial_id: b7640_00002
# (run pid=1118)
# (run pid=1118) Result for DQN_SimpleCorridor_b7640_00001:
# (run pid=1118)   agent_timesteps_total: 2000
# (run pid=1118)   custom_metrics: {}
# (run pid=1118)   date: 2022-01-11_20-04-55
# (run pid=1118)   done: false
# (run pid=1118)   episode_len_mean: 25.883116883116884
# (run pid=1118)   episode_media: {}
# (run pid=1118)   episode_reward_max: 1.0912095629578384
# (run pid=1118)   episode_reward_mean: -1.4862976911723524
# (run pid=1118)   episode_reward_min: -11.902361019422154
# (run pid=1118)   episodes_this_iter: 46
# (run pid=1118)   episodes_total: 77
# (run pid=1118)   experiment_id: 1701d7fc35984e78a6ec77d94b20b4e8
# (run pid=1118)   hostname: ray-61ddddeb0bbd833830273b3e-ray-worker-3
# (run pid=1118)   info:
# (run pid=1118)     last_target_update_ts: 1504
# (run pid=1118)     learner:
# (run pid=1118)       default_policy:
# (run pid=1118)         custom_metrics: {}
# (run pid=1118)         learner_stats:
# (run pid=1118)           allreduce_latency: 0.0
# (run pid=1118)           cur_lr: 0.0001
# (run pid=1118)           grad_gnorm: 0.1990833282470703
# (run pid=1118)           max_q: 0.8584766983985901
# (run pid=1118)           mean_q: 0.6782430410385132
# (run pid=1118)           min_q: 0.3541158437728882
# (run pid=1118)         mean_td_error: -0.11369509249925613
# (run pid=1118)         model: {}
# (run pid=1118)         td_error:
# (run pid=1118)         - -0.10212850570678711
# (run pid=1118)         - 0.7340917587280273
# (run pid=1118)         - 0.0012589693069458008
# (run pid=1118)         - -0.08475494384765625
# (run pid=1118)         - 0.0012589693069458008
# (run pid=1118)         - -0.10212850570678711
# (run pid=1118)         - -0.14707159996032715
# (run pid=1118)         - -0.14707159996032715
# (run pid=1118)         - -0.14707159996032715
# (run pid=1118)         - 0.0012589693069458008
# (run pid=1118)         - 0.0012589693069458008
# (run pid=1118)         - -0.09080153703689575
# (run pid=1118)         - -0.961225688457489
# (run pid=1118)         - 0.035563766956329346
# (run pid=1118)         - -0.10212850570678711
# (run pid=1118)         - 0.0012589693069458008
# (run pid=1118)         - 0.721336841583252
# (run pid=1118)         - -0.08408337831497192
# (run pid=1118)         - -0.053353577852249146
# (run pid=1118)         - 0.0012589693069458008
# (run pid=1118)         - -0.053353577852249146
# (run pid=1118)         - 0.035563766956329346
# (run pid=1118)         - -0.6236398816108704
# (run pid=1118)         - 0.0012589693069458008
# (run pid=1118)         - -0.7043166756629944
# (run pid=1118)         - -0.6236398816108704
# (run pid=1118)         - -0.08408337831497192
# (run pid=1118)         - -0.8411542773246765
# (run pid=1118)         - -0.08475494384765625
# (run pid=1118)         - 0.0012589693069458008
# (run pid=1118)         - -0.08475476503372192
# (run pid=1118)         - -0.053354114294052124
# (run pid=1118)     num_agent_steps_sampled: 2000
# (run pid=1118)     num_agent_steps_trained: 8032
# (run pid=1118)     num_steps_sampled: 2000
# (run pid=1118)     num_steps_trained: 8032
# (run pid=1118)     num_steps_trained_this_iter: 0
# (run pid=1118)     num_target_updates: 2
# (run pid=1118)   iterations_since_restore: 2
# (run pid=1118)   node_ip: 10.0.35.140
# (run pid=1118)   num_healthy_workers: 0
# (run pid=1118)   off_policy_estimator: {}
# (run pid=1118)   perf:
# (run pid=1118)     cpu_util_percent: 14.485714285714286
# (run pid=1118)     ram_util_percent: 10.6
# (run pid=1118)   pid: 365
# (run pid=1118)   policy_reward_max: {}
# (run pid=1118)   policy_reward_mean: {}
# (run pid=1118)   policy_reward_min: {}
# (run pid=1118)   sampler_perf:
# (run pid=1118)     mean_action_processing_ms: 0.06577120967807251
# (run pid=1118)     mean_env_render_ms: 0.0
# (run pid=1118)     mean_env_wait_ms: 0.051325551359417264
# (run pid=1118)     mean_inference_ms: 1.6008684743329817
# (run pid=1118)     mean_raw_obs_processing_ms: 0.18582410721510273
# (run pid=1118)   time_since_restore: 7.6033549308776855
# (run pid=1118)   time_this_iter_s: 5.388041257858276
# (run pid=1118)   time_total_s: 7.6033549308776855
# (run pid=1118)   timers:
# (run pid=1118)     learn_throughput: 3709.937
# (run pid=1118)     learn_time_ms: 8.625
# (run pid=1118)     load_throughput: 107909.413
# (run pid=1118)     load_time_ms: 0.297
# (run pid=1118)   timestamp: 1641931495
# (run pid=1118)   timesteps_since_restore: 0
# (run pid=1118)   timesteps_this_iter: 0
# (run pid=1118)   timesteps_total: 2000
# (run pid=1118)   training_iteration: 2
# (run pid=1118)   trial_id: b7640_00001
# (run pid=1118)
# (scheduler +2m34s) Error: No available node types can fulfill resource request {'GPU': 1.0, 'CPU': 1.0}. Add suitable node types to this cluster to resolve this issue.
# (run pid=1118) == Status ==
# (run pid=1118) Current time: 2022-01-11 20:04:59 (running for 00:00:16.62)
# (run pid=1118) Memory usage on this node: 4.2/31.4 GiB
# (run pid=1118) Using FIFO scheduling algorithm.
# (run pid=1118) Resources requested: 3.0/30 CPUs, 0/0 GPUs, 0.0/91.6 GiB heap, 0.0/40.41 GiB objects
# (run pid=1118) Result logdir: /domino/datasets/local/Ray_Quick_Start/DQN
# (run pid=1118) Number of trials: 3/3 (3 RUNNING)
# (run pid=1118) +--------------------------------+----------+-----------------+--------+--------+------------------+------+-----------+----------------------+----------------------+--------------------+
# (run pid=1118) | Trial name                     | status   | loc             |     lr |   iter |   total time (s) |   ts |    reward |   episode_reward_max |   episode_reward_min |   episode_len_mean |
# (run pid=1118) |--------------------------------+----------+-----------------+--------+--------+------------------+------+-----------+----------------------+----------------------+--------------------|
# (run pid=1118) | DQN_SimpleCorridor_b7640_00000 | RUNNING  | 10.0.60.133:240 | 0.01   |      2 |          7.0413  | 2000 | -1.49527  |              1.44236 |            -19.2112  |            26.8919 |
# (run pid=1118) | DQN_SimpleCorridor_b7640_00001 | RUNNING  | 10.0.35.140:365 | 0.0001 |      2 |          7.60335 | 2000 | -1.4863   |              1.09121 |            -11.9024  |            25.8831 |
# (run pid=1118) | DQN_SimpleCorridor_b7640_00002 | RUNNING  | 10.0.45.20:365  | 1e-06  |      2 |          7.46626 | 2000 | -0.638649 |              1.29924 |             -7.78155 |            18.15   |
# (run pid=1118) +--------------------------------+----------+-----------------+--------+--------+------------------+------+-----------+----------------------+----------------------+--------------------+
# (run pid=1118)
# (run pid=1118)
# (run pid=1119) == Status ==
# (run pid=1119) Current time: 2022-01-11 20:04:59 (running for 00:02:25.79)
# (run pid=1119) Memory usage on this node: 4.2/31.4 GiB
# (run pid=1119) Using FIFO scheduling algorithm.
# (run pid=1119) Resources requested: 0/30 CPUs, 0/0 GPUs, 0.0/91.6 GiB heap, 0.0/40.41 GiB objects
# (run pid=1119) Result logdir: /domino/datasets/local/Ray_Quick_Start/DQN
# (run pid=1119) Number of trials: 3/3 (3 PENDING)
# (run pid=1119) +--------------------------------+----------+-------+--------+
# (run pid=1119) | Trial name                     | status   | loc   |     lr |
# (run pid=1119) |--------------------------------+----------+-------+--------|
# (run pid=1119) | DQN_SimpleCorridor_6a7de_00000 | PENDING  |       | 0.01   |
# (run pid=1119) | DQN_SimpleCorridor_6a7de_00001 | PENDING  |       | 0.0001 |
# (run pid=1119) | DQN_SimpleCorridor_6a7de_00002 | PENDING  |       | 1e-06  |
# (run pid=1119) +--------------------------------+----------+-------+--------+
# (run pid=1119)
# (run pid=1119)
# (run pid=1118) Result for DQN_SimpleCorridor_b7640_00000:
# (run pid=1118)   agent_timesteps_total: 3000
# (run pid=1118)   custom_metrics: {}
# (run pid=1118)   date: 2022-01-11_20-05-00
# (run pid=1118)   done: false
# (run pid=1118)   episode_len_mean: 31.684782608695652
# (run pid=1118)   episode_media: {}
# (run pid=1118)   episode_reward_max: 1.442363981051137
# (run pid=1118)   episode_reward_mean: -2.0131596465061348
# (run pid=1118)   episode_reward_min: -20.780281923514398
# (run pid=1118)   episodes_this_iter: 18
# (run pid=1118)   episodes_total: 92
# (run pid=1118)   experiment_id: 5142525d048c4f86ac65025dd714721b
# (run pid=1118)   hostname: ray-61ddddeb0bbd833830273b3e-ray-worker-0
# (run pid=1118)   info:
# (run pid=1118)     last_target_update_ts: 2512
# (run pid=1118)     learner:
# (run pid=1118)       default_policy:
# (run pid=1118)         custom_metrics: {}
# (run pid=1118)         learner_stats:
# (run pid=1118)           allreduce_latency: 0.0
# (run pid=1118)           cur_lr: 0.01
# (run pid=1118)           grad_gnorm: 0.5701093077659607
# (run pid=1118)           max_q: 6.645701885223389
# (run pid=1118)           mean_q: 6.371935844421387
# (run pid=1118)           min_q: 6.171159744262695
# (run pid=1118)         mean_td_error: 0.5630611777305603
# (run pid=1118)         model: {}
# (run pid=1118)         td_error:
# (run pid=1118)         - 6.1232008934021
# (run pid=1118)         - 0.04103279113769531
# (run pid=1118)         - -0.39478635787963867
# (run pid=1118)         - -0.3445119857788086
# (run pid=1118)         - 0.04103279113769531
# (run pid=1118)         - -0.3445119857788086
# (run pid=1118)         - 6.1232008934021
# (run pid=1118)         - -0.11548709869384766
# (run pid=1118)         - -0.12982511520385742
# (run pid=1118)         - -0.3445119857788086
# (run pid=1118)         - -0.1327648162841797
# (run pid=1118)         - -0.1327648162841797
# (run pid=1118)         - -0.12982511520385742
# (run pid=1118)         - 4.804162979125977
# (run pid=1118)         - -0.11548709869384766
# (run pid=1118)         - -0.3445119857788086
# (run pid=1118)         - 6.10125207901001
# (run pid=1118)         - -0.39478635787963867
# (run pid=1118)         - -0.11548709869384766
# (run pid=1118)         - -0.16778898239135742
# (run pid=1118)         - -0.12982511520385742
# (run pid=1118)         - -0.4014773368835449
# (run pid=1118)         - 0.04103279113769531
# (run pid=1118)         - -0.39478635787963867
# (run pid=1118)         - -0.11548709869384766
# (run pid=1118)         - -0.12982511520385742
# (run pid=1118)         - -0.12982511520385742
# (run pid=1118)         - -0.16778898239135742
# (run pid=1118)         - -0.16778898239135742
# (run pid=1118)         - -0.12982511520385742
# (run pid=1118)         - -0.11548662185668945
# (run pid=1118)         - -0.16778945922851562
# (run pid=1118)     num_agent_steps_sampled: 3000
# (run pid=1118)     num_agent_steps_trained: 16032
# (run pid=1118)     num_steps_sampled: 3000
# (run pid=1118)     num_steps_trained: 16032
# (run pid=1118)     num_steps_trained_this_iter: 0
# (run pid=1118)     num_target_updates: 4
# (run pid=1118)   iterations_since_restore: 3
# (run pid=1118)   node_ip: 10.0.60.133
# (run pid=1118)   num_healthy_workers: 0
# (run pid=1118)   off_policy_estimator: {}
# (run pid=1118)   perf:
# (run pid=1118)     cpu_util_percent: 14.257142857142856
# (run pid=1118)     ram_util_percent: 10.571428571428571
# (run pid=1118)   pid: 240
# (run pid=1118)   policy_reward_max: {}
# (run pid=1118)   policy_reward_mean: {}
# (run pid=1118)   policy_reward_min: {}
# (run pid=1118)   sampler_perf:
# (run pid=1118)     mean_action_processing_ms: 0.05990384832991737
# (run pid=1118)     mean_env_render_ms: 0.0
# (run pid=1118)     mean_env_wait_ms: 0.04880199191425184
# (run pid=1118)     mean_inference_ms: 1.49399968099902
# (run pid=1118)     mean_raw_obs_processing_ms: 0.17020093386437551
# (run pid=1118)   time_since_restore: 12.030189037322998
# (run pid=1118)   time_this_iter_s: 4.988887548446655
# (run pid=1118)   time_total_s: 12.030189037322998
# (run pid=1118)   timers:
# (run pid=1118)     learn_throughput: 4080.298
# (run pid=1118)     learn_time_ms: 7.843
# (run pid=1118)     load_throughput: 120786.292
# (run pid=1118)     load_time_ms: 0.265
# (run pid=1118)   timestamp: 1641931500
# (run pid=1118)   timesteps_since_restore: 0
# (run pid=1118)   timesteps_this_iter: 0
# (run pid=1118)   timesteps_total: 3000
# (run pid=1118)   training_iteration: 3
# (run pid=1118)   trial_id: b7640_00000
# (run pid=1118)
# (run pid=1118) Result for DQN_SimpleCorridor_b7640_00002:
# (run pid=1118)   agent_timesteps_total: 3000
# (run pid=1118)   custom_metrics: {}
# (run pid=1118)   date: 2022-01-11_20-05-00
# (run pid=1118)   done: false
# (run pid=1118)   episode_len_mean: 17.24
# (run pid=1118)   episode_media: {}
# (run pid=1118)   episode_reward_max: 1.4730096151253476
# (run pid=1118)   episode_reward_mean: -0.6094466793103231
# (run pid=1118)   episode_reward_min: -4.745168652694244
# (run pid=1118)   episodes_this_iter: 57
# (run pid=1118)   episodes_total: 162
# (run pid=1118)   experiment_id: bf4eb87322334aa5b212549c9412c3af
# (run pid=1118)   hostname: ray-61ddddeb0bbd833830273b3e-ray-worker-2
# (run pid=1118)   info:
# (run pid=1118)     last_target_update_ts: 2512
# (run pid=1118)     learner:
# (run pid=1118)       default_policy:
# (run pid=1118)         custom_metrics: {}
# (run pid=1118)         learner_stats:
# (run pid=1118)           allreduce_latency: 0.0
# (run pid=1118)           cur_lr: 1.0e-06
# (run pid=1118)           grad_gnorm: 0.07073912769556046
# (run pid=1118)           max_q: 0.891872227191925
# (run pid=1118)           mean_q: 0.41863250732421875
# (run pid=1118)           min_q: 0.0026000388897955418
# (run pid=1118)         mean_td_error: -0.20620812475681305
# (run pid=1118)         model: {}
# (run pid=1118)         td_error:
# (run pid=1118)         - -0.2976674437522888
# (run pid=1118)         - 0.46921205520629883
# (run pid=1118)         - -0.7168387770652771
# (run pid=1118)         - 0.46921205520629883
# (run pid=1118)         - -0.7168387770652771
# (run pid=1118)         - -0.9196892380714417
# (run pid=1118)         - 0.46921205520629883
# (run pid=1118)         - 0.0919116735458374
# (run pid=1118)         - -0.2976674437522888
# (run pid=1118)         - -0.23073118925094604
# (run pid=1118)         - 0.0919116735458374
# (run pid=1118)         - -0.7168387770652771
# (run pid=1118)         - 0.46921205520629883
# (run pid=1118)         - -0.7168387770652771
# (run pid=1118)         - 0.46921205520629883
# (run pid=1118)         - 0.2584680914878845
# (run pid=1118)         - 0.05396085977554321
# (run pid=1118)         - -0.7168387770652771
# (run pid=1118)         - 0.8913658261299133
# (run pid=1118)         - -0.7168387770652771
# (run pid=1118)         - 0.0919116735458374
# (run pid=1118)         - -0.7168387770652771
# (run pid=1118)         - -0.9883577227592468
# (run pid=1118)         - 0.05396085977554321
# (run pid=1118)         - -0.7168387770652771
# (run pid=1118)         - -0.9391563534736633
# (run pid=1118)         - -0.23073118925094604
# (run pid=1118)         - 0.061516404151916504
# (run pid=1118)         - -0.014963269233703613
# (run pid=1118)         - -0.7168387770652771
# (run pid=1118)         - 0.06151694059371948
# (run pid=1118)         - -0.23073118925094604
# (run pid=1118)     num_agent_steps_sampled: 3000
# (run pid=1118)     num_agent_steps_trained: 16032
# (run pid=1118)     num_steps_sampled: 3000
# (run pid=1118)     num_steps_trained: 16032
# (run pid=1118)     num_steps_trained_this_iter: 0
# (run pid=1118)     num_target_updates: 4
# (run pid=1118)   iterations_since_restore: 3
# (run pid=1118)   node_ip: 10.0.45.20
# (run pid=1118)   num_healthy_workers: 0
# (run pid=1118)   off_policy_estimator: {}
# (run pid=1118)   perf:
# (run pid=1118)     cpu_util_percent: 14.342857142857142
# (run pid=1118)     ram_util_percent: 10.700000000000001
# (run pid=1118)   pid: 365
# (run pid=1118)   policy_reward_max: {}
# (run pid=1118)   policy_reward_mean: {}
# (run pid=1118)   policy_reward_min: {}
# (run pid=1118)   sampler_perf:
# (run pid=1118)     mean_action_processing_ms: 0.06289061229721903
# (run pid=1118)     mean_env_render_ms: 0.0
# (run pid=1118)     mean_env_wait_ms: 0.050532057159178884
# (run pid=1118)     mean_inference_ms: 1.5509151539643882
# (run pid=1118)     mean_raw_obs_processing_ms: 0.18396797728686917
# (run pid=1118)   time_since_restore: 12.741263628005981
# (run pid=1118)   time_this_iter_s: 5.27500581741333
# (run pid=1118)   time_total_s: 12.741263628005981
# (run pid=1118)   timers:
# (run pid=1118)     learn_throughput: 3940.939
# (run pid=1118)     learn_time_ms: 8.12
# (run pid=1118)     load_throughput: 123441.302
# (run pid=1118)     load_time_ms: 0.259
# (run pid=1118)   timestamp: 1641931500
# (run pid=1118)   timesteps_since_restore: 0
# (run pid=1118)   timesteps_this_iter: 0
# (run pid=1118)   timesteps_total: 3000
# (run pid=1118)   training_iteration: 3
# (run pid=1118)   trial_id: b7640_00002
# (run pid=1118)
# (run pid=1118) Result for DQN_SimpleCorridor_b7640_00001:
# (run pid=1118)   agent_timesteps_total: 3000
# (run pid=1118)   custom_metrics: {}
# (run pid=1118)   date: 2022-01-11_20-05-00
# (run pid=1118)   done: false
# (run pid=1118)   episode_len_mean: 21.91
# (run pid=1118)   episode_media: {}
# (run pid=1118)   episode_reward_max: 1.1783930246791954
# (run pid=1118)   episode_reward_mean: -1.0948431578079416
# (run pid=1118)   episode_reward_min: -6.8042445454313105
# (run pid=1118)   episodes_this_iter: 49
# (run pid=1118)   episodes_total: 126
# (run pid=1118)   experiment_id: 1701d7fc35984e78a6ec77d94b20b4e8
# (run pid=1118)   hostname: ray-61ddddeb0bbd833830273b3e-ray-worker-3
# (run pid=1118)   info:
# (run pid=1118)     last_target_update_ts: 2512
# (run pid=1118)     learner:
# (run pid=1118)       default_policy:
# (run pid=1118)         custom_metrics: {}
# (run pid=1118)         learner_stats:
# (run pid=1118)           allreduce_latency: 0.0
# (run pid=1118)           cur_lr: 0.0001
# (run pid=1118)           grad_gnorm: 0.010709443129599094
# (run pid=1118)           max_q: 0.7950548529624939
# (run pid=1118)           mean_q: 0.7058660387992859
# (run pid=1118)           min_q: 0.564229428768158
# (run pid=1118)         mean_td_error: -0.01423737034201622
# (run pid=1118)         model: {}
# (run pid=1118)         td_error:
# (run pid=1118)         - -1.0347602367401123
# (run pid=1118)         - 0.02081596851348877
# (run pid=1118)         - 0.04408806562423706
# (run pid=1118)         - 0.09195619821548462
# (run pid=1118)         - -0.05766874551773071
# (run pid=1118)         - -0.7677385210990906
# (run pid=1118)         - 0.02446722984313965
# (run pid=1118)         - -0.05766874551773071
# (run pid=1118)         - 0.04408806562423706
# (run pid=1118)         - 0.09195619821548462
# (run pid=1118)         - -0.05766874551773071
# (run pid=1118)         - 0.09195619821548462
# (run pid=1118)         - -0.003821074962615967
# (run pid=1118)         - -0.14792662858963013
# (run pid=1118)         - 0.02446722984313965
# (run pid=1118)         - 0.018142104148864746
# (run pid=1118)         - 0.018142104148864746
# (run pid=1118)         - 0.10222524404525757
# (run pid=1118)         - -0.05766874551773071
# (run pid=1118)         - 0.04408806562423706
# (run pid=1118)         - 0.02446722984313965
# (run pid=1118)         - -0.003821074962615967
# (run pid=1118)         - 0.09195619821548462
# (run pid=1118)         - 0.02446722984313965
# (run pid=1118)         - 0.02446722984313965
# (run pid=1118)         - 0.09195619821548462
# (run pid=1118)         - 0.7458586096763611
# (run pid=1118)         - -0.05766874551773071
# (run pid=1118)         - 0.10222524404525757
# (run pid=1118)         - -0.05766874551773071
# (run pid=1118)         - 0.024467647075653076
# (run pid=1118)         - 0.1022258996963501
# (run pid=1118)     num_agent_steps_sampled: 3000
# (run pid=1118)     num_agent_steps_trained: 16032
# (run pid=1118)     num_steps_sampled: 3000
# (run pid=1118)     num_steps_trained: 16032
# (run pid=1118)     num_steps_trained_this_iter: 0
# (run pid=1118)     num_target_updates: 4
# (run pid=1118)   iterations_since_restore: 3
# (run pid=1118)   node_ip: 10.0.35.140
# (run pid=1118)   num_healthy_workers: 0
# (run pid=1118)   off_policy_estimator: {}
# (run pid=1118)   perf:
# (run pid=1118)     cpu_util_percent: 14.3
# (run pid=1118)     ram_util_percent: 10.6
# (run pid=1118)   pid: 365
# (run pid=1118)   policy_reward_max: {}
# (run pid=1118)   policy_reward_mean: {}
# (run pid=1118)   policy_reward_min: {}
# (run pid=1118)   sampler_perf:
# (run pid=1118)     mean_action_processing_ms: 0.06551139186329254
# (run pid=1118)     mean_env_render_ms: 0.0
# (run pid=1118)     mean_env_wait_ms: 0.05151154556480687
# (run pid=1118)     mean_inference_ms: 1.5520555360241122
# (run pid=1118)     mean_raw_obs_processing_ms: 0.18894488281448993
# (run pid=1118)   time_since_restore: 12.96106767654419
# ...
# (run pid=1119) | DQN_SimpleCorridor_6a7de_00002 | PENDING  |       | 1e-06  |
# (run pid=1119) +--------------------------------+----------+-------+--------+
# (run pid=1119)
# (run pid=1119)
# (run pid=1119) == Status ==
# (run pid=1119) Current time: 2022-01-11 20:07:50 (running for 00:05:16.43)
# (run pid=1119) Memory usage on this node: 4.2/31.4 GiB
# (run pid=1119) Using FIFO scheduling algorithm.
# (run pid=1119) Resources requested: 0/30 CPUs, 0/0 GPUs, 0.0/91.6 GiB heap, 0.0/40.41 GiB objects
# (run pid=1119) Result logdir: /domino/datasets/local/Ray_Quick_Start/DQN
# (run pid=1119) Number of trials: 3/3 (3 PENDING)
# (run pid=1119) +--------------------------------+----------+-------+--------+
# (run pid=1119) | Trial name                     | status   | loc   |     lr |
# (run pid=1119) |--------------------------------+----------+-------+--------|
# (run pid=1119) | DQN_SimpleCorridor_6a7de_00000 | PENDING  |       | 0.01   |
# (run pid=1119) | DQN_SimpleCorridor_6a7de_00001 | PENDING  |       | 0.0001 |
# (run pid=1119) | DQN_SimpleCorridor_6a7de_00002 | PENDING  |       | 1e-06  |
# (run pid=1119) +--------------------------------+----------+-------+--------+
# (run pid=1119)
# (run pid=1119)
# (scheduler +5m29s) Error: No available node types can fulfill resource request {'GPU': 1.0, 'CPU': 1.0}. Add suitable node types to this cluster to resolve this issue.
# (run pid=1119) == Status ==
# (run pid=1119) Current time: 2022-01-11 20:07:55 (running for 00:05:21.46)
# (run pid=1119) Memory usage on this node: 4.2/31.4 GiB
# (run pid=1119) Using FIFO scheduling algorithm.
# (run pid=1119) Resources requested: 0/30 CPUs, 0/0 GPUs, 0.0/91.6 GiB heap, 0.0/40.41 GiB objects
# (run pid=1119) Result logdir: /domino/datasets/local/Ray_Quick_Start/DQN
# (run pid=1119) Number of trials: 3/3 (3 PENDING)
# (run pid=1119) +--------------------------------+----------+-------+--------+
# (run pid=1119) | Trial name                     | status   | loc   |     lr |
# (run pid=1119) |--------------------------------+----------+-------+--------|
# (run pid=1119) | DQN_SimpleCorridor_6a7de_00000 | PENDING  |       | 0.01   |
# (run pid=1119) | DQN_SimpleCorridor_6a7de_00001 | PENDING  |       | 0.0001 |
# (run pid=1119) | DQN_SimpleCorridor_6a7de_00002 | PENDING  |       | 1e-06  |
# (run pid=1119) +--------------------------------+----------+-------+--------+
# (run pid=1119)
# (run pid=1119)
# (run pid=1119) == Status ==
# (run pid=1119) Current time: 2022-01-11 20:08:00 (running for 00:05:26.46)
# (run pid=1119) Memory usage on this node: 4.2/31.4 GiB
# (run pid=1119) Using FIFO scheduling algorithm.
# (run pid=1119) Resources requested: 0/30 CPUs, 0/0 GPUs, 0.0/91.6 GiB heap, 0.0/40.41 GiB objects
# (run pid=1119) Result logdir: /domino/datasets/local/Ray_Quick_Start/DQN
# (run pid=1119) Number of trials: 3/3 (3 PENDING)
# (run pid=1119) +--------------------------------+----------+-------+--------+
# (run pid=1119) | Trial name                     | status   | loc   |     lr |
# (run pid=1119) |--------------------------------+----------+-------+--------|
# (run pid=1119) | DQN_SimpleCorridor_6a7de_00000 | PENDING  |       | 0.01   |
# (run pid=1119) | DQN_SimpleCorridor_6a7de_00001 | PENDING  |       | 0.0001 |
# (run pid=1119) | DQN_SimpleCorridor_6a7de_00002 | PENDING  |       | 1e-06  |
# (run pid=1119) +--------------------------------+----------+-------+--------+
# (run pid=1119)
# (run pid=1119)
# (run pid=1119) == Status ==
# (run pid=1119) Current time: 2022-01-11 20:08:05 (running for 00:05:31.50)
# (run pid=1119) Memory usage on this node: 4.2/31.4 GiB
# (run pid=1119) Using FIFO scheduling algorithm.
# (run pid=1119) Resources requested: 0/30 CPUs, 0/0 GPUs, 0.0/91.6 GiB heap, 0.0/40.41 GiB objects
# (run pid=1119) Result logdir: /domino/datasets/local/Ray_Quick_Start/DQN
# (run pid=1119) Number of trials: 3/3 (3 PENDING)
# (run pid=1119) +--------------------------------+----------+-------+--------+
# (run pid=1119) | Trial name                     | status   | loc   |     lr |
# (run pid=1119) |--------------------------------+----------+-------+--------|
# (run pid=1119) | DQN_SimpleCorridor_6a7de_00000 | PENDING  |       | 0.01   |
# (run pid=1119) | DQN_SimpleCorridor_6a7de_00001 | PENDING  |       | 0.0001 |
# (run pid=1119) | DQN_SimpleCorridor_6a7de_00002 | PENDING  |       | 1e-06  |
# (run pid=1119) +--------------------------------+----------+-------+--------+
# (run pid=1119)
# (run pid=1119)
# (run pid=1119) == Status ==
# (run pid=1119) Current time: 2022-01-11 20:08:10 (running for 00:05:36.50)
# (run pid=1119) Memory usage on this node: 4.2/31.4 GiB
# (run pid=1119) Using FIFO scheduling algorithm.
# (run pid=1119) Resources requested: 0/30 CPUs, 0/0 GPUs, 0.0/91.6 GiB heap, 0.0/40.41 GiB objects
# (run pid=1119) Result logdir: /domino/datasets/local/Ray_Quick_Start/DQN
# (run pid=1119) Number of trials: 3/3 (3 PENDING)
# (run pid=1119) +--------------------------------+----------+-------+--------+
# (run pid=1119) | Trial name                     | status   | loc   |     lr |
# (run pid=1119) |--------------------------------+----------+-------+--------|
# (run pid=1119) | DQN_SimpleCorridor_6a7de_00000 | PENDING  |       | 0.01   |
# (run pid=1119) | DQN_SimpleCorridor_6a7de_00001 | PENDING  |       | 0.0001 |
# (run pid=1119) | DQN_SimpleCorridor_6a7de_00002 | PENDING  |       | 1e-06  |
# (run pid=1119) +--------------------------------+----------+-------+--------+
# (run pid=1119)
# (run pid=1119)
# (run pid=1119) == Status ==
# (run pid=1119) Current time: 2022-01-11 20:08:15 (running for 00:05:41.53)
# (run pid=1119) Memory usage on this node: 4.2/31.4 GiB
# (run pid=1119) Using FIFO scheduling algorithm.
# (run pid=1119) Resources requested: 0/30 CPUs, 0/0 GPUs, 0.0/91.6 GiB heap, 0.0/40.41 GiB objects
# (run pid=1119) Result logdir: /domino/datasets/local/Ray_Quick_Start/DQN
# (run pid=1119) Number of trials: 3/3 (3 PENDING)
# (run pid=1119) +--------------------------------+----------+-------+--------+
# (run pid=1119) | Trial name                     | status   | loc   |     lr |
# (run pid=1119) |--------------------------------+----------+-------+--------|
# (run pid=1119) | DQN_SimpleCorridor_6a7de_00000 | PENDING  |       | 0.01   |
# (run pid=1119) | DQN_SimpleCorridor_6a7de_00001 | PENDING  |       | 0.0001 |
# (run pid=1119) | DQN_SimpleCorridor_6a7de_00002 | PENDING  |       | 1e-06  |
# (run pid=1119) +--------------------------------+----------+-------+--------+
# (run pid=1119)
# (run pid=1119)
# (run pid=1119) == Status ==
# (run pid=1119) Current time: 2022-01-11 20:08:20 (running for 00:05:46.53)
# (run pid=1119) Memory usage on this node: 4.2/31.4 GiB
# (run pid=1119) Using FIFO scheduling algorithm.
# (run pid=1119) Resources requested: 0/30 CPUs, 0/0 GPUs, 0.0/91.6 GiB heap, 0.0/40.41 GiB objects
# (run pid=1119) Result logdir: /domino/datasets/local/Ray_Quick_Start/DQN
# (run pid=1119) Number of trials: 3/3 (3 PENDING)
# (run pid=1119) +--------------------------------+----------+-------+--------+
# (run pid=1119) | Trial name                     | status   | loc   |     lr |
# (run pid=1119) |--------------------------------+----------+-------+--------|
# (run pid=1119) | DQN_SimpleCorridor_6a7de_00000 | PENDING  |       | 0.01   |
# (run pid=1119) | DQN_SimpleCorridor_6a7de_00001 | PENDING  |       | 0.0001 |
# (run pid=1119) | DQN_SimpleCorridor_6a7de_00002 | PENDING  |       | 1e-06  |
# (run pid=1119) +--------------------------------+----------+-------+--------+
# (run pid=1119)
# (run pid=1119)
# (run pid=1119) == Status ==
# (run pid=1119) Current time: 2022-01-11 20:08:25 (running for 00:05:51.56)
# (run pid=1119) Memory usage on this node: 4.2/31.4 GiB
# (run pid=1119) Using FIFO scheduling algorithm.
# (run pid=1119) Resources requested: 0/30 CPUs, 0/0 GPUs, 0.0/91.6 GiB heap, 0.0/40.41 GiB objects
# (run pid=1119) Result logdir: /domino/datasets/local/Ray_Quick_Start/DQN
# (run pid=1119) Number of trials: 3/3 (3 PENDING)
# (run pid=1119) +--------------------------------+----------+-------+--------+
# (run pid=1119) | Trial name                     | status   | loc   |     lr |
# (run pid=1119) |--------------------------------+----------+-------+--------|
# (run pid=1119) | DQN_SimpleCorridor_6a7de_00000 | PENDING  |       | 0.01   |
# (run pid=1119) | DQN_SimpleCorridor_6a7de_00001 | PENDING  |       | 0.0001 |
# (run pid=1119) | DQN_SimpleCorridor_6a7de_00002 | PENDING  |       | 1e-06  |
# (run pid=1119) +--------------------------------+----------+-------+--------+
# (run pid=1119)
# (run pid=1119)
# (scheduler +6m4s) Error: No available node types can fulfill resource request {'CPU': 1.0, 'GPU': 1.0}. Add suitable node types to this cluster to resolve this issue.
# (run pid=1119) == Status ==
# (run pid=1119) Current time: 2022-01-11 20:08:30 (running for 00:05:56.56)
# (run pid=1119) Memory usage on this node: 4.2/31.4 GiB
# (run pid=1119) Using FIFO scheduling algorithm.
# (run pid=1119) Resources requested: 0/30 CPUs, 0/0 GPUs, 0.0/91.6 GiB heap, 0.0/40.41 GiB objects
# (run pid=1119) Result logdir: /domino/datasets/local/Ray_Quick_Start/DQN
# (run pid=1119) Number of trials: 3/3 (3 PENDING)
# (run pid=1119) +--------------------------------+----------+-------+--------+
# (run pid=1119) | Trial name                     | status   | loc   |     lr |
# (run pid=1119) |--------------------------------+----------+-------+--------|
# (run pid=1119) | DQN_SimpleCorridor_6a7de_00000 | PENDING  |       | 0.01   |
# (run pid=1119) | DQN_SimpleCorridor_6a7de_00001 | PENDING  |       | 0.0001 |
# (run pid=1119) | DQN_SimpleCorridor_6a7de_00002 | PENDING  |       | 1e-06  |
# (run pid=1119) +--------------------------------+----------+-------+--------+
# (run pid=1119)
# (run pid=1119)
# (run pid=1119) 2022-01-11 20:08:34,216	WARNING trial_executor.py:312 -- Ignore this message if the cluster is autoscaling. You asked for 1.0 cpu and 1.0 gpu per trial, but the cluster only has 30.0 cpu and 0 gpu. Stop the tuning job and adjust the resources requested per trial (possibly via `resources_per_trial` or via `num_workers` for rllib) and/or add more resources to your Ray runtime.
# (run pid=1119) == Status ==
# (run pid=1119) Current time: 2022-01-11 20:08:35 (running for 00:06:01.59)
# (run pid=1119) Memory usage on this node: 4.2/31.4 GiB
# (run pid=1119) Using FIFO scheduling algorithm.
# (run pid=1119) Resources requested: 0/30 CPUs, 0/0 GPUs, 0.0/91.6 GiB heap, 0.0/40.41 GiB objects
# (run pid=1119) Result logdir: /domino/datasets/local/Ray_Quick_Start/DQN
# (run pid=1119) Number of trials: 3/3 (3 PENDING)
# (run pid=1119) +--------------------------------+----------+-------+--------+
# (run pid=1119) | Trial name                     | status   | loc   |     lr |
# (run pid=1119) |--------------------------------+----------+-------+--------|
# (run pid=1119) | DQN_SimpleCorridor_6a7de_00000 | PENDING  |       | 0.01   |
# (run pid=1119) | DQN_SimpleCorridor_6a7de_00001 | PENDING  |       | 0.0001 |
# (run pid=1119) | DQN_SimpleCorridor_6a7de_00002 | PENDING  |       | 1e-06  |
# (run pid=1119) +--------------------------------+----------+-------+--------+
# (run pid=1119)
# (run pid=1119)
# (run pid=1119) == Status ==
# (run pid=1119) Current time: 2022-01-11 20:08:40 (running for 00:06:06.60)
# (run pid=1119) Memory usage on this node: 4.2/31.4 GiB
# (run pid=1119) Using FIFO scheduling algorithm.
# (run pid=1119) Resources requested: 0/30 CPUs, 0/0 GPUs, 0.0/91.6 GiB heap, 0.0/40.41 GiB objects
# (run pid=1119) Result logdir: /domino/datasets/local/Ray_Quick_Start/DQN
# (run pid=1119) Number of trials: 3/3 (3 PENDING)
# (run pid=1119) +--------------------------------+----------+-------+--------+
# (run pid=1119) | Trial name                     | status   | loc   |     lr |
# (run pid=1119) |--------------------------------+----------+-------+--------|
# (run pid=1119) | DQN_SimpleCorridor_6a7de_00000 | PENDING  |       | 0.01   |
# (run pid=1119) | DQN_SimpleCorridor_6a7de_00001 | PENDING  |       | 0.0001 |
# (run pid=1119) | DQN_SimpleCorridor_6a7de_00002 | PENDING  |       | 1e-06  |
# (run pid=1119) +--------------------------------+----------+-------+--------+
# (run pid=1119)
# (run pid=1119)
# (run pid=1119) == Status ==
# (run pid=1119) Current time: 2022-01-11 20:08:45 (running for 00:06:11.63)
# (run pid=1119) Memory usage on this node: 4.2/31.4 GiB
# (run pid=1119) Using FIFO scheduling algorithm.
# (run pid=1119) Resources requested: 0/30 CPUs, 0/0 GPUs, 0.0/91.6 GiB heap, 0.0/40.41 GiB objects
# (run pid=1119) Result logdir: /domino/datasets/local/Ray_Quick_Start/DQN
# (run pid=1119) Number of trials: 3/3 (3 PENDING)
# (run pid=1119) +--------------------------------+----------+-------+--------+
# (run pid=1119) | Trial name                     | status   | loc   |     lr |
# (run pid=1119) |--------------------------------+----------+-------+--------|
# (run pid=1119) | DQN_SimpleCorridor_6a7de_00000 | PENDING  |       | 0.01   |
# (run pid=1119) | DQN_SimpleCorridor_6a7de_00001 | PENDING  |       | 0.0001 |
# (run pid=1119) | DQN_SimpleCorridor_6a7de_00002 | PENDING  |       | 1e-06  |
# (run pid=1119) +--------------------------------+----------+-------+--------+
# (run pid=1119)
# (run pid=1119)
# (run pid=1119) == Status ==
# (run pid=1119) Current time: 2022-01-11 20:08:50 (running for 00:06:16.63)
# (run pid=1119) Memory usage on this node: 4.2/31.4 GiB
# (run pid=1119) Using FIFO scheduling algorithm.
# (run pid=1119) Resources requested: 0/30 CPUs, 0/0 GPUs, 0.0/91.6 GiB heap, 0.0/40.41 GiB objects
# (run pid=1119) Result logdir: /domino/datasets/local/Ray_Quick_Start/DQN
# (run pid=1119) Number of trials: 3/3 (3 PENDING)
# (run pid=1119) +--------------------------------+----------+-------+--------+
# (run pid=1119) | Trial name                     | status   | loc   |     lr |
# (run pid=1119) |--------------------------------+----------+-------+--------|
# (run pid=1119) | DQN_SimpleCorridor_6a7de_00000 | PENDING  |       | 0.01   |
# (run pid=1119) | DQN_SimpleCorridor_6a7de_00001 | PENDING  |       | 0.0001 |
# (run pid=1119) | DQN_SimpleCorridor_6a7de_00002 | PENDING  |       | 1e-06  |
# (run pid=1119) +--------------------------------+----------+-------+--------+
# (run pid=1119)
# (run pid=1119)
# (run pid=1119) == Status ==
# (run pid=1119) Current time: 2022-01-11 20:08:55 (running for 00:06:21.67)
# (run pid=1119) Memory usage on this node: 4.2/31.4 GiB
# (run pid=1119) Using FIFO scheduling algorithm.
# (run pid=1119) Resources requested: 0/30 CPUs, 0/0 GPUs, 0.0/91.6 GiB heap, 0.0/40.41 GiB objects
# (run pid=1119) Result logdir: /domino/datasets/local/Ray_Quick_Start/DQN
# (run pid=1119) Number of trials: 3/3 (3 PENDING)
# (run pid=1119) +--------------------------------+----------+-------+--------+
# (run pid=1119) | Trial name                     | status   | loc   |     lr |
# (run pid=1119) |--------------------------------+----------+-------+--------|
# (run pid=1119) | DQN_SimpleCorridor_6a7de_00000 | PENDING  |       | 0.01   |
# (run pid=1119) | DQN_SimpleCorridor_6a7de_00001 | PENDING  |       | 0.0001 |
# (run pid=1119) | DQN_SimpleCorridor_6a7de_00002 | PENDING  |       | 1e-06  |
# (run pid=1119) +--------------------------------+----------+-------+--------+
# (run pid=1119)
# (run pid=1119)
# (run pid=1119) == Status ==
# (run pid=1119) Current time: 2022-01-11 20:09:00 (running for 00:06:26.67)
# (run pid=1119) Memory usage on this node: 4.2/31.4 GiB
# (run pid=1119) Using FIFO scheduling algorithm.
# (run pid=1119) Resources requested: 0/30 CPUs, 0/0 GPUs, 0.0/91.6 GiB heap, 0.0/40.41 GiB objects
# (run pid=1119) Result logdir: /domino/datasets/local/Ray_Quick_Start/DQN
# (run pid=1119) Number of trials: 3/3 (3 PENDING)
# (run pid=1119) +--------------------------------+----------+-------+--------+
# (run pid=1119) | Trial name                     | status   | loc   |     lr |
# (run pid=1119) |--------------------------------+----------+-------+--------|
# (run pid=1119) | DQN_SimpleCorridor_6a7de_00000 | PENDING  |       | 0.01   |
# (run pid=1119) | DQN_SimpleCorridor_6a7de_00001 | PENDING  |       | 0.0001 |
# (run pid=1119) | DQN_SimpleCorridor_6a7de_00002 | PENDING  |       | 1e-06  |
# (run pid=1119) +--------------------------------+----------+-------+--------+
# (run pid=1119)
# (run pid=1119)

# %% [markdown]
# ### A Note about Warnings
#
# Version 1.6 is validated on the latest edition of Domino, but you see here we chose to use the latest stable version of Ray, 1.9.  This version will occasionally throw some warning about depreciation for future versions of Ray or Pytorch because it is the newest stable version of Ray.  Don't worry too much about the warnings, they will not change the procedures followed to run the code.
#
#
# ### What's Next?
#
# *Using Pytorch and Ray for a simple finance example using DQN*
